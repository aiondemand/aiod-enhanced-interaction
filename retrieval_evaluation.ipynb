# %%
from typing import Literal
import os
import json
import sys
import pandas as pd

src_dir = os.path.abspath('./src')
sys.path.append(src_dir)

from evaluation.metrics import RetrievalMetrics, SpecificAssetQueriesMetrics
# Out:
# /home/marveso/miniconda3/envs/tailor/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# # Query generation

# %% [markdown]
# ### Generic queries
#
# Three levels of descriptiveness:
# - `least_descriptive` -> *A concise user query, up to 70 characters, capturing only the essential and most significant properties of the dataset.*
#
# - `moderately_descriptive` -> *A detailed user query, up to 200 characters, providing additional information and properties to offer a clearer description of the dataset*
#
# - `most_descriptive` -> *A comprehensive user query, up to 500 characters, encompassing a wide range of details and characteristics to thoroughly describe the dataset.*

# %%
generic_queries_path = "data/queries/generic"

for lvl in ["least_descriptive", "moderately_descriptive", "most_descriptive"]:
    print(f"DESCRIPTIVENESS LEVEL: {lvl}")
    
    with open(os.path.join(generic_queries_path, f"{lvl}.json")) as f:
        queries = json.load(f)

    for q in queries[:3]:
        print(q["text"])
    print("\n\n")
# Out:
# DESCRIPTIVENESS LEVEL: least_descriptive
# image classification dataset
# text summarization data
# speech recognition dataset
#
#
#
# DESCRIPTIVENESS LEVEL: moderately_descriptive
# datasets for image classification tasks with labels
# text summarization datasets in English language
# speech recognition datasets with transcriptions
#
#
#
# DESCRIPTIVENESS LEVEL: most_descriptive
# image classification datasets with high-resolution images, labeled categories, and balanced class distribution
# text summarization datasets in English, containing news articles, summaries, and metadata
# speech recognition datasets with transcriptions, audio recordings in various accents, and noise levels

# %% [markdown]
# ----
#
# ### Asset-specific queries
#
# Four asset categories to evaluate:
# - `long_description_many_tags`
#
# - `long_description_few_tags`
#
# - `moderate_description_many_tags`
#
# - `poor_description_many_tags`
#
# Three levels of descriptiveness:
# - `least_descriptive`
#
# - `moderately_descriptive`
#
# - `most_descriptive`

# %% [markdown]
# #### Assets with good description

# %%
def get_asset_specific_queries_examples(asset_cat):
    asset_specific_queries_path = "data/queries/asset-specific"
    text_dirpath = "data/basic-texts"
    descrip_level = ["least_descriptive", "moderately_descriptive", "most_descriptive"]

    queries = [[],[],[]]
    docs = []
    for lvl_it, lvl in enumerate(descrip_level):
        path = os.path.join(asset_specific_queries_path, f"{lvl}-{asset_cat}.json")
        with open(path) as f:
            data = json.load(f)
        q = [obj["text"] for obj in data[:2]]
        queries[lvl_it].extend(q)
        
        if lvl_it == 0:
            doc_ids = [obj["annotated_docs"][0]["id"] for obj in data[:2]]
            for doc_id in doc_ids:
                with open(os.path.join(text_dirpath, f"{doc_id}.txt")) as f:
                    docs.append(f.read())
    
    return docs, queries

# %%
def print_out_assets(docs, queries):
    descrip_level = ["least_descriptive", "moderately_descriptive", "most_descriptive"]
    
    for it, (doc, least_q, moder_q, most_q) in enumerate(zip(docs, *queries)):
        print(f"============ DOCUMENT {it} ============")
        print(doc)

        print("\n")
        print(f"{descrip_level[0]} query: {least_q}")
        print(f"{descrip_level[1]} query: {moder_q}")
        print(f"{descrip_level[2]} query: {most_q}")

        print("\n\n\n")

# %%
docs, queries = get_asset_specific_queries_examples(asset_cat="long_description_many_tags")
print_out_assets(docs, queries)
# Out:
# ============ DOCUMENT 0 ============
# Platform: huggingface
# Asset name: ddrg/super_eurlex
# Description: Super-EURLEX dataset containing legal documents from multiple languages.
#                 The datasets are build/scrapped from the EURLEX Website [https://eur-lex.europa.eu/homepage.html]
#                 With one split per language and sector, because the available features (metadata) differs for each
#                 sector. Therefore, each sample contains the content of a full legal document in up to 3 different
#                 formats. Those are raw HTML and cleaned HTML (if the HTML format was available on the EURLEX website
#                 during the scrapping process) and cleaned text.
#                 The cleaned text should be available for each sample and was extracted from HTML or PDF.
#                 'Cleaned' HTML stands here for minor cleaning that was done to preserve to a large extent the necessary
#                 HTML information like table structures while removing unnecessary complexity which was introduced to the
#                 original documents due to actions like writing each sentence into a new object.
#                 Additionally, each sample contains metadata which was scrapped on the fly, this implies the following
#                 2 things. First, not every sector contains the same metadata. Second, most metadata might be
#                 irrelevant for most use cases.
#                 In our minds the most interesting metadata is the celex-id which is used to identify the legal
#                 document at hand, but also contains a lot of information about the document
#                 see [https://eur-lex.europa.eu/content/tools/eur-lex-celex-infographic-A3.pdf] as well as eurovoc-
#                 concepts, which are labels that define the content of the documents.
#                 Eurovoc-Concepts are, for example, only available  [...]
# Keywords: source_datasets:original | language:en | region:us | language_creators:found | license:mit | task_categories:text-classification | annotations_creators:found | task_categories:fill-mask | language:pl | language:fr | multilinguality:multilingual | size_categories:1m<n<10m | language:es | language:de | language:pt | task_ids:multi-class-classification | language:nl | language:ro | language:lt | language:it | language:cs | language:sv | language:sl | language:sk | language:hu | language:el | language:lv | language:fi | language:hr | language:et | language:da | language:bg | task_ids:multi-label-classification | language:ga | language:mt | corpus | eurlex | html | legal documents
#
#
# least_descriptive query: Multilingual legal documents dataset with metadata and cleaned text
# moderately_descriptive query: Dataset of legal documents from EURLEX in multiple languages with metadata, including cleaned text and HTML formats
# most_descriptive query: Multilingual dataset of legal documents from EURLEX, containing raw and cleaned HTML, cleaned text, and metadata like celex-id and eurovoc-concepts. Each document is available in up to 3 formats (raw HTML, cleaned HTML, cleaned text). Metadata varies per sector, and the dataset is suitable for text classification and fill-mask tasks.
#
#
#
#
# ============ DOCUMENT 1 ============
# Platform: huggingface
# Asset name: anton-l/superb
# Description: Self-supervised learning (SSL) has proven vital for advancing research in
# natural language processing (NLP) and computer vision (CV). The paradigm
# pretrains a shared model on large volumes of unlabeled data and achieves
# state-of-the-art (SOTA) for various tasks with minimal adaptation. However, the
# speech processing community lacks a similar setup to systematically explore the
# paradigm. To bridge this gap, we introduce Speech processing Universal
# PERformance Benchmark (SUPERB). SUPERB is a leaderboard to benchmark the
# performance of a shared model across a wide range of speech processing tasks
# with minimal architecture changes and labeled data. Among multiple usages of the
# shared model, we especially focus on extracting the representation learned from
# SSL due to its preferable re-usability. We present a simple framework to solve
# SUPERB tasks by learning task-specialized lightweight prediction heads on top of
# the frozen shared model. Our results demonstrate that the framework is promising
# as SSL representations show competitive generalizability and accessibility
# across SUPERB tasks. We release SUPERB as a challenge with a leaderboard and a
# benchmark toolkit to fuel the research in representation learning and general
# speech processing.
#
# Note that in order to limit the required storage for preparing this dataset, the
# audio is stored in the .wav format and is not converted to a float32 array. To
# convert the audio file to a float32 array, please make use of the `.map()`
# function as follows:
#
#
# ```python
# import soundfile as sf
#
# def map_to_array(batch):
#     speech_array, _ = sf.read(batch["file"])
#     batch["speech"] = speech_array
#     return batch
#
# dataset = dataset.map(map_to_array, remove_columns=["file"])
# ```
# Keywords: source_datasets:original | multilinguality:monolingual | language:en | region:us | license:unknown | size_categories:unknown | task_ids:intent-classification | language_creators:other | annotations_creators:other | task_ids:slot-filling | task_ids:speaker-identification | task_ids:keyword-spotting | source_datasets:extended|other-librimix | source_datasets:extended|other-speech_commands | source_datasets:extended|librispeech_asr | arxiv:2105.01051
#
#
# least_descriptive query: speech processing SSL benchmark for various tasks
# moderately_descriptive query: self-supervised learning benchmark for speech tasks with minimal model changes
# most_descriptive query: benchmark for speech processing using self-supervised learning with a shared model, focusing on extracting SSL representations for tasks like speaker identification, keyword spotting, and intent classification

# %% [markdown]
# #### Assets with little to no description

# %%
docs, queries = get_asset_specific_queries_examples(asset_cat="poor_description_many_tags")
print_out_assets(docs, queries)
# Out:
# ============ DOCUMENT 0 ============
# Platform: huggingface
# Asset name: KBLab/overlim
# Description: \
# Keywords: region:us | task_categories:text-classification | task_ids:sentiment-classification | task_ids:text-scoring | multilinguality:translation | license:cc-by-4.0 | size_categories:unknown | task_ids:natural-language-inference | language:sv | language:da | language_creators:other | annotations_creators:other | qa-nli | task_ids:semantic-similarity-classification | language:nb | paraphrase-identification | source_datasets:extended|glue | source_datasets:extended|super_glue
#
#
# least_descriptive query: Sentiment classification dataset for Nordic languages
# moderately_descriptive query: Dataset for sentiment classification and text scoring in Swedish, Danish, and Norwegian
# most_descriptive query: Multilingual dataset for sentiment classification, text scoring, and natural language inference in Swedish, Danish, and Norwegian. Includes tasks like semantic similarity classification and paraphrase identification. Licensed under cc-by-4.0, sourced from extended GLUE and Super GLUE datasets.
#
#
#
#
# ============ DOCUMENT 1 ============
# Platform: huggingface
# Asset name: castorini/afriberta-corpus
# Description: Corpus used for training AfriBERTa models
# Keywords: region:us | task_ids:language-modeling | task_categories:text-generation | license:apache-2.0 | language:so | language:am | language:om | language:ha | language:ig | language:yo | language:sw | language:ti | language:rw | language:rn | language:pcm | language:multilingual
#
#
# least_descriptive query: Corpus for training multilingual language models
# moderately_descriptive query: Corpus for training language models in multiple African languages (so, am, om, ha, ig, yo, sw, ti, rw, rn, pcm)
# most_descriptive query: A comprehensive corpus for training language models, encompassing a wide range of African languages including Somali, Amharic, Oromo, Hausa, Igbo, Yoruba, Swahili, Tigrinya, Kinyarwanda, Kirundi, and Nigerian Pidgin, suitable for tasks in language modeling and text generation. Licensed under Apache-2.0.

# %% [markdown]
# ----

# %% [markdown]
# # Preliminary results of evaluation of retrieval systems
#
# #### Aspects that were evaluated:
#
# - **embedding models**
#     - working with document embeddings => GTE large / multilingual E5
#     - working with chunk embeddings => BGE large / multilingual E5
#
# - **text processing** -> relevant fields / basic fields
#
# - **evaluation pipelines**
#     - precision evaluation -> AI scores VS heuristic scores
#     - hit-rate evaluation

# %% [markdown]
# ### Embedding models
#
# **GTE**
# - `Alibaba-NLP/gte-large-en-v1.5`
# - encoder-only architecture, 430M params
# - english language
# - input size: 4k
#
# **E5**
# - `intfloat/multilingual-e5-large`
# - encoder-only architecture, 560M params
# - multilingual model
# - input size: 512 (need for chunking)
#
# **BGE**
# - `BAAI/bge-large-en-v1.5`
# - encoder-only architecture, 335M params
# - english language
# - input size: 512 (need for chunking)

# %% [markdown]
# ### Text processing
#
# **Relevant fields**
# - extract all the seemingly relevant fields from the documents
#
# **Basic fields**
# - take only: platform, name, description, tags

# %%
doc_id = "315961"

with open(os.path.join("./data/relevant-texts", f"{doc_id}.txt")) as f:
    rel_doc = f.read()
with open(os.path.join("./data/basic-texts", f"{doc_id}.txt")) as f:
    basic_doc = f.read()

# %%
print("RELEVANT FIELDS\n")
print(rel_doc)
# Out:
# RELEVANT FIELDS
#
# platform: zenodo
# name: Unpublished data on birds feeding on dead honey bees
# date_published: 2022-08-09T00:00:00
# year_published: 2022
# month_published: 8
# day_published: 9
# description: The data were collected by me during two years with the aim to initiate a larger research project. However, I neither found the time nor the research funding for the project. Hence, I decided to upload the data so they may be used for a scientific publication, preliminary data set for a similar project, or any other research. About 2500 observations of birds visiting six honey bee colonies are available in the excel file.
# keyword: ecology, bird, apis mellifera, honeybee, parus major, animal behaviour, pica pica, unpulished
# DISTRIBUTION:
# 	name:Counts_All_2017_2018.xlsx, encoding_format:application/octet-stream
# 	name:Background_Material_Methods.docx, encoding_format:application/octet-stream
# 	name:sitesID-FolderID.xlsx, encoding_format:application/octet-stream
# 	name:Examples sites.zip, encoding_format:application/zip

# %%
print("BASIC FIELDS\n")
print(basic_doc)
# Out:
# BASIC FIELDS
#
# Platform: zenodo
# Asset name: Unpublished data on birds feeding on dead honey bees
# Description: The data were collected by me during two years with the aim to initiate a larger research project. However, I neither found the time nor the research funding for the project. Hence, I decided to upload the data so they may be used for a scientific publication, preliminary data set for a similar project, or any other research. About 2500 observations of birds visiting six honey bee colonies are available in the excel file.
# Keywords: ecology | bird | apis mellifera | honeybee | parus major | animal behaviour | pica pica | unpulished

# %% [markdown]
# # Precision evaluation
#
# - Retrieve top K (K=10) most similar documents to the **GENERIC QUERIES**
# - Utilize LLM-as-a-judge to estimate the relevance of retrieved documents to queries
# - Compute retrieval precision

# %%
model_variants = [
    # basic dataset representations
    "gte_large--basic",
    "multilingual_e5_large--basic",
    "multilingual_e5_large--CHUNK_EMBEDS--basic",
    "bge_large--CHUNK_EMBEDS--basic",

    # relevant dataset representations
    "gte_large--relevant",
    "multilingual_e5_large--relevant",   
    "multilingual_e5_large--CHUNK_EMBEDS--relevant",
    "bge_large--CHUNK_EMBEDS--relevant"
]

# %%
def highlight_precision(s: pd.Series):
    is_max = s == s.max()
    is_second_max = s == sorted(s.unique())[-2] if len(s.unique()) > 1 else s == s.max()
    return ['background-color: rgba(255, 0, 0, 0.3); color: white' if v else 'background-color: rgba(255, 165, 0, 0.3); color: white' if is_second_max[idx] else '' for idx, v in is_max.items()]

# %%
def add_middle_border(df):
    horizontal_border_style = {
        'selector': 'td:nth-child({})'.format(len(df.columns) // 2 + 1),
        'props': [('border-right', '4px solid white')]
    }
    df =  df.set_table_styles([horizontal_border_style], overwrite=False)

    vertical_border_style = {
        'selector': 'tr:nth-child({})'.format(len(df.index) // 2),
        'props': [('border-bottom', '4px solid white')]
    }
    return  df.set_table_styles([vertical_border_style], overwrite=False)

# %%
def create_precision_results_dataframe(
    model_variants: list[str],
    descriptiveness_level: Literal["least_descriptive", "moderately_descriptive", "most_descriptive", "all"] = "all", 
    function_score: Literal["llm_scores", "heuristic_scores"] = "llm_scores"
) -> pd.DataFrame:
    precision_results_path = "data/results/precision"
    metric_col_names = [
        "prec@3", "prec@5", "prec@10",
        "ndcg@3", "ndcg@5", "ndcg@10"
    ]
    dataframe_rows = [[] for _ in range(len(model_variants))]
    for it_var, var in enumerate(model_variants):
        path = os.path.join(
            precision_results_path, var, descriptiveness_level, f"{function_score}_results.json"
        )
        with open(path) as f:
            metrics = RetrievalMetrics.load(json.load(f))
        
        dataframe_rows[it_var].append(var)
        for col_name in metric_col_names:
            m_name, k = col_name.split("@")
            m_value = getattr(metrics.results_in_top[k], m_name)
            dataframe_rows[it_var].append(m_value)    
        
    df = pd.DataFrame(data=dataframe_rows, columns=["Input Config"] + metric_col_names)
    df = df.set_index(keys=["Input Config"], drop=True)
    
    index_values = df.index.values
    df = df.style.apply(highlight_precision, subset=pd.IndexSlice[index_values[: len(df.index) // 2], df.columns])
    df = df.apply(highlight_precision, subset=pd.IndexSlice[index_values[len(df.index) // 2:], df.columns])

    df = add_middle_border(df)
    return df

# %% [markdown]
# ### LLM predictions

# %% [markdown]
# **Least_descriptive queries** (10 evaluated generic queries)

# %%
least_df = create_precision_results_dataframe(model_variants, descriptiveness_level="least_descriptive", function_score="llm_scores")
least_df
# Out:
# <style type="text/css">
# #T_6ee84 td:nth-child(4) {
#   border-right: 4px solid white;
# }
# #T_6ee84 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_6ee84_row0_col0, #T_6ee84_row0_col1, #T_6ee84_row0_col2, #T_6ee84_row0_col3, #T_6ee84_row0_col5, #T_6ee84_row3_col4, #T_6ee84_row4_col0, #T_6ee84_row4_col2, #T_6ee84_row4_col4, #T_6ee84_row4_col5, #T_6ee84_row6_col1, #T_6ee84_row7_col3 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_6ee84_row1_col4, #T_6ee84_row1_col5, #T_6ee84_row2_col3, #T_6ee84_row3_col0, #T_6ee84_row3_col1, #T_6ee84_row3_col2, #T_6ee84_row4_col1, #T_6ee84_row4_col3, #T_6ee84_row7_col0, #T_6ee84_row7_col1, #T_6ee84_row7_col2, #T_6ee84_row7_col4, #T_6ee84_row7_col5 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_6ee84">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ee84_level0_col0" class="col_heading level0 col0" >prec@3</th>
#       <th id="T_6ee84_level0_col1" class="col_heading level0 col1" >prec@5</th>
#       <th id="T_6ee84_level0_col2" class="col_heading level0 col2" >prec@10</th>
#       <th id="T_6ee84_level0_col3" class="col_heading level0 col3" >ndcg@3</th>
#       <th id="T_6ee84_level0_col4" class="col_heading level0 col4" >ndcg@5</th>
#       <th id="T_6ee84_level0_col5" class="col_heading level0 col5" >ndcg@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ee84_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_6ee84_row0_col0" class="data row0 col0" >0.766667</td>
#       <td id="T_6ee84_row0_col1" class="data row0 col1" >0.800000</td>
#       <td id="T_6ee84_row0_col2" class="data row0 col2" >0.800000</td>
#       <td id="T_6ee84_row0_col3" class="data row0 col3" >0.972676</td>
#       <td id="T_6ee84_row0_col4" class="data row0 col4" >0.937512</td>
#       <td id="T_6ee84_row0_col5" class="data row0 col5" >0.942396</td>
#     </tr>
#     <tr>
#       <th id="T_6ee84_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T
td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Moderately_descriptive queries** (30 evaluated generic queries)

# %%
moderate_df = create_precision_results_dataframe(model_variants, descriptiveness_level="moderately_descriptive", function_score="llm_scores")
moderate_df
# Out:
# <style type="text/css">
# #T_c57d1 td:nth-child(4) {
#   border-right: 4px solid white;
# }
# #T_c57d1 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_c57d1_row0_col0, #T_c57d1_row0_col1, #T_c57d1_row0_col2, #T_c57d1_row0_col3, #T_c57d1_row0_col4, #T_c57d1_row0_col5, #T_c57d1_row4_col0, #T_c57d1_row4_col1, #T_c57d1_row4_col2, #T_c57d1_row4_col3, #T_c57d1_row4_col4, #T_c57d1_row4_col5 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# #T_c57d1_row2_col0, #T_c57d1_row2_col4, #T_c57d1_row2_col5, #T_c57d1_row3_col1, #T_c57d1_row3_col2, #T_c57d1_row3_col3, #T_c57d1_row5_col3, #T_c57d1_row5_col4, #T_c57d1_row5_col5, #T_c57d1_row7_col0, #T_c57d1_row7_col1, #T_c57d1_row7_col2 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_c57d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c57d1_level0_col0" class="col_heading level0 col0" >prec@3</th>
#       <th id="T_c57d1_level0_col1" class="col_heading level0 col1" >prec@5</th>
#       <th id="T_c57d1_level0_col2" class="col_heading level0 col2" >prec@10</th>
#       <th id="T_c57d1_level0_col3" class="col_heading level0 col3" >ndcg@3</th>
#       <th id="T_c57d1_level0_col4" class="col_heading level0 col4" >ndcg@5</th>
#       <th id="T_c57d1_level0_col5" class="col_heading level0 col5" >ndcg@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c57d1_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_c57d1_row0_col0" class="data row0 col0" >0.888889</td>
#       <td id="T_c57d1_row0_col1" class="data row0 col1" >0.860000</td>
#       <td id="T_c57d1_row0_col2" class="data row0 col2" >0.840000</td>
#       <td id="T_c57d1_row0_col3" class="data row0 col3" >0.985571</td>
#       <td id="T_c57d1_row0_col4" class="data row0 col4" >0.969686</td>
#       <td id="T_c57d1_row0_col5" class="data row0 col5" >0.963227</td>
#     </tr>
#     <tr>
#       <th id="T_c57d1_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_c57d1_row1_col0" class="data row1 col0" >0.622222</td>
#       <td id="T_c57d1_row1_col1" class="data row1 col1" >0.626667</td>
#       <td id="T_c57d1_row1_col2" class="data row1 col2" >0.570000</td>
#       <td id="T_c57d1_row1_col3" class="data row1 col3" >0.937279</td>
#       <td id="T_c57d1_row1_col4" class="data row1 col4" >0.906974</td>
#       <td id="T_c57d1_row1_col5" class="data row1 col5" >0.894725</td>
#     </tr>
#     <tr>
#       <th id="T_c57d1_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_c57d1_row2_col0" class="data row2 col0" >0.722222</td>
#       <td id="T_c57d1_row2_col1" class="data row2 col1" >0.680000</td>
#       <td id="T_c57d1_row2_col2" class="data row2 col2" >0.633333</td>
#       <td id="T_c57d1_row2_col3" class="data row2 col3" >0.945122</td>
#       <td id="T_c57d1_row2_col4" class="data row2 col4" >0.927554</td>
#       <td id="T_c57d1_row2_col5" class="data row2 col5" >0.918066</td>
#     </tr>
#     <tr>
#       <th id="T_c57d1_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_c57d1_row3_col0" class="data row3 col0" >0.722222</td>
#       <td id="T_c57d1_row3_col1" class="data row3 col1" >0.693333</td>
#       <td id="T_c57d1_row3_col2" class="data row3 col2" >0.713333</td>
#       <td id="T_c57d1_row3_col3" class="data row3 col3" >0.946026</td>
#       <td id="T_c57d1_row3_col4" class="data row3 col4" >0.921762</td>
#       <td id="T_c57d1_row3_col5" class="data row3 col5" >0.907321</td>
#     </tr>
#     <tr>
#       <th id="T_c57d1_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_c57d1_row4_col0" class="data row4 col0" >0.877778</td>
#       <td id="T_c57d1_row4_col1" class="data row4 col1" >0.826667</td>
#       <td id="T_c57d1_row4_col2" class="data row4 col2" >0.806667</td>
#       <td id="T_c57d1_row4_col3" class="data row4 col3" >0.969002</td>
#       <td id="T_c57d1_row4_col4" class="data row4 col4" >0.959832</td>
#       <td id="T_c57d1_row4_col5" class="data row4 col5" >0.953724</td>
#     </tr>
#     <tr>
#       <th id="T_c57d1_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_c57d1_row5_col0" class="data row5 col0" >0.600000</td>
#       <td id="T_c57d1_row5_col1" class="data row5 col1" >0.573333</td>
#       <td id="T_c57d1_row5_col2" class="data row5 col2" >0.523333</td>
#       <td id="T_c57d1_row5_col3" class="data row5 col3" >0.962599</td>
#       <td id="T_c57d1_row5_col4" class="data row5 col4" >0.954739</td>
#       <td id="T_c57d1_row5_col5" class="data row5 col5" >0.944011</td>
#     </tr>
#     <tr>
#       <th id="T_c57d1_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_c57d1_row6_col0" class="data row6 col0" >0.655556</td>
#       <td id="T_c57d1_row6_col1" class="data row6 col1" >0.640000</td>
#       <td id="T_c57d1_row6_col2" class="data row6 col2" >0.583333</td>
#       <td id="T_c57d1_row6_col3" class="data row6 col3" >0.940617</td>
#       <td id="T_c57d1_row6_col4" class="data row6 col4" >0.927743</td>
#       <td id="T_c57d1_row6_col5" class="data row6 col5" >0.918019</td>
#     </tr>
#     <tr>
#       <th id="T_c57d1_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_c57d1_row7_col0" class="data row7 col0" >0.733333</td>
#       <td id="T_c57d1_row7_col1" class="data row7 col1" >0.773333</td>
#       <td id="T_c57d1_row7_col2" class="data row7 col2" >0.760000</td>
#       <td id="T_c57d1_row7_col3" class="data row7 col3" >0.946369</td>
#       <td id="T_c57d1_row7_col4" class="data row7 col4" >0.934562</td>
#       <td id="T_c57d1_row7_col5" class="data row7 col5" >0.926124</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Most_descriptive queries** (50 evaluated generic queries)

# %%
most_df = create_precision_results_dataframe(model_variants, descriptiveness_level="most_descriptive", function_score="llm_scores")
most_df
# Out:
# <style type="text/css">
# #T_09594 td:nth-child(4) {
#   border-right: 4px solid white;
# }
# #T_09594 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_09594_row0_col0, #T_09594_row0_col1, #T_09594_row0_col2, #T_09594_row0_col3, #T_09594_row0_col4, #T_09594_row0_col5, #T_09594_row4_col0, #T_09594_row4_col1, #T_09594_row4_col2, #T_09594_row4_col3, #T_09594_row4_col4, #T_09594_row4_col5 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# #T_09594_row1_col3, #T_09594_row1_col4, #T_09594_row1_col5, #T_09594_row3_col0, #T_09594_row3_col1, #T_09594_row3_col2, #T_09594_row7_col0, #T_09594_row7_col1, #T_09594_row7_col2, #T_09594_row7_col3, #T_09594_row7_col4, #T_09594_row7_col5 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_09594">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09594_level0_col0" class="col_heading level0 col0" >prec@3</th>
#       <th id="T_09594_level0_col1" class="col_heading level0 col1" >prec@5</th>
#       <th id="T_09594_level0_col2" class="col_heading level0 col2" >prec@10</th>
#       <th id="T_09594_level0_col3" class="col_heading level0 col3" >ndcg@3</th>
#       <th id="T_09594_level0_col4" class="col_heading level0 col4" >ndcg@5</th>
#       <th id="T_09594_level0_col5" class="col_heading level0 col5" >ndcg@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09594_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_09594_row0_col0" class="data row0 col0" >0.574074</td>
#       <td id="T_09594_row0_col1" class="data row0 col1" >0.537037</td>
#       <td id="T_09594_row0_col2" class="data row0 col2" >0.496296</td>
#       <td id="T_09594_row0_col3" class="data row0 col3" >0.955986</td>
#       <td id="T_09594_row0_col4" class="data row0 col4" >0.938104</td>
#       <td id="T_09594_row0_col5" class="data row0 col5" >0.915184</td>
#     </tr>
#     <tr>
#       <th id="T_09594_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_09594_row1_col0" class="data row1 col0" >0.382716</td>
#       <td id="T_09594_row1_col1" class="data row1 col1" >0.377778</td>
#       <td id="T_09594_row1_col2" class="data row1 col2" >0.359259</td>
#       <td id="T_09594_row1_col3" class="data row1 col3" >0.942299</td>
#       <td id="T_09594_row1_col4" class="data row1 col4" >0.914320</td>
#       <td id="T_09594_row1_col5" class="data row1 col5" >0.893017</td>
#     </tr>
#     <tr>
#       <th id="T_09594_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_09594_row2_col0" class="data row2 col0" >0.345679</td>
#       <td id="T_09594_row2_col1" class="data row2 col1" >0.344444</td>
#       <td id="T_09594_row2_col2" class="data row2 col2" >0.361111</td>
#       <td id="T_09594_row2_col3" class="data row2 col3" >0.938123</td>
#       <td id="T_09594_row2_col4" class="data row2 col4" >0.912004</td>
#       <td id="T_09594_row2_col5" class="data row2 col5" >0.867619</td>
#     </tr>
#     <tr>
#       <th id="T_09594_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_09594_row3_col0" class="data row3 col0" >0.481481</td>
#       <td id="T_09594_row3_col1" class="data row3 col1" >0.455556</td>
#       <td id="T_09594_row3_col2" class="data row3 col2" >0.466667</td>
#       <td id="T_09594_row3_col3" class="data row3 col3" >0.932391</td>
#       <td id="T_09594_row3_col4" class="data row3 col4" >0.909394</td>
#       <td id="T_09594_row3_col5" class="data row3 col5" >0.868128</td>
#     </tr>
#     <tr>
#       <th id="T_09594_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_09594_row4_col0" class="data row4 col0" >0.753086</td>
#       <td id="T_09594_row4_col1" class="data row4 col1" >0.696296</td>
#       <td id="T_09594_row4_col2" class="data row4 col2" >0.637037</td>
#       <td id="T_09594_row4_col3" class="data row4 col3" >0.946030</td>
#       <td id="T_09594_row4_col4" class="data row4 col4" >0.932958</td>
#       <td id="T_09594_row4_col5" class="data row4 col5" >0.916135</td>
#     </tr>
#     <tr>
#       <th id="T_09594_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_09594_row5_col0" class="data row5 col0" >0.413580</td>
#       <td id="T_09594_row5_col1" class="data row5 col1" >0.388889</td>
#       <td id="T_09594_row5_col2" class="data row5 col2" >0.366667</td>
#       <td id="T_09594_row5_col3" class="data row5 col3" >0.931780</td>
#       <td id="T_09594_row5_col4" class="data row5 col4" >0.921610</td>
#       <td id="T_09594_row5_col5" class="data row5 col5" >0.896210</td>
#     </tr>
#     <tr>
#       <th id="T_09594_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_09594_row6_col0" class="data row6 col0" >0.438272</td>
#       <td id="T_09594_row6_col1" class="data row6 col1" >0.433333</td>
#       <td id="T_09594_row6_col2" class="data row6 col2" >0.400000</td>
#       <td id="T_09594_row6_col3" class="data row6 col3" >0.941046</td>
#       <td id="T_09594_row6_col4" class="data row6 col4" >0.905147</td>
#       <td id="T_09594_row6_col5" class="data row6 col5" >0.895709</td>
#     </tr>
#     <tr>
#       <th id="T_09594_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_09594_row7_col0" class="data row7 col0" >0.598765</td>
#       <td id="T_09594_row7_col1" class="data row7 col1" >0.596296</td>
#       <td id="T_09594_row7_col2" class="data row7 col2" >0.590741</td>
#       <td id="T_09594_row7_col3" class="data row7 col3" >0.942958</td>
#       <td id="T_09594_row7_col4" class="data row7 col4" >0.922455</td>
#       <td id="T_09594_row7_col5" class="data row7 col5" >0.896240</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **All queries** (90 queries)

# %%
all_df = create_precision_results_dataframe(model_variants, descriptiveness_level="all", function_score="llm_scores")
all_df
# Out:
# <style type="text/css">
# #T_7d5a3 td:nth-child(4) {
#   border-right: 4px solid white;
# }
# #T_7d5a3 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_7d5a3_row0_col0, #T_7d5a3_row0_col1, #T_7d5a3_row0_col2, #T_7d5a3_row0_col3, #T_7d5a3_row0_col4, #T_7d5a3_row0_col5, #T_7d5a3_row4_col0, #T_7d5a3_row4_col1, #T_7d5a3_row4_col2, #T_7d5a3_row4_col3, #T_7d5a3_row4_col4, #T_7d5a3_row4_col5 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# #T_7d5a3_row1_col5, #T_7d5a3_row2_col3, #T_7d5a3_row2_col4, #T_7d5a3_row3_col0, #T_7d5a3_row3_col1, #T_7d5a3_row3_col2, #T_7d5a3_row5_col4, #T_7d5a3_row5_col5, #T_7d5a3_row7_col0, #T_7d5a3_row7_col1, #T_7d5a3_row7_col2, #T_7d5a3_row7_col3 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_7d5a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d5a3_level0_col0" class="col_heading level0 col0" >prec@3</th>
#       <th id="T_7d5a3_level0_col1" class="col_heading level0 col1" >prec@5</th>
#       <th id="T_7d5a3_level0_col2" class="col_heading level0 col2" >prec@10</th>
#       <th id="T_7d5a3_level0_col3" class="col_heading level0 col3" >ndcg@3</th>
#       <th id="T_7d5a3_level0_col4" class="col_heading level0 col4" >ndcg@5</th>
#       <th id="T_7d5a3_level0_col5" class="col_heading level0 col5" >ndcg@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d5a3_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_7d5a3_row0_col0" class="data row0 col0" >0.695035</td>
#       <td id="T_7d5a3_row0_col1" class="data row0 col1" >0.668085</td>
#       <td id="T_7d5a3_row0_col2" class="data row0 col2" >0.638298</td>
#       <td id="T_7d5a3_row0_col3" class="data row0 col3" >0.967204</td>
#       <td id="T_7d5a3_row0_col4" class="data row0 col4" >0.948121</td>
#       <td id="T_7d5a3_row0_col5" class="data row0 col5" >0.933412</td>
#     </tr>
#     <tr>
#       <th id="T_7d5a3_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_7d5a3_row1_col0" class="data row1 col0" >0.496454</td>
#       <td id="T_7d5a3_row1_col1" class="data row1 col1" >0.495745</td>
#       <td id="T_7d5a3_row1_col2" class="data row1 col2" >0.465957</td>
#       <td id="T_7d5a3_row1_col3" class="data row1 col3" >0.943030</td>
#       <td id="T_7d5a3_row1_col4" class="data row1 col4" >0.916582</td>
#       <td id="T_7d5a3_row1_col5" class="data row1 col5" >0.899780</td>
#     </tr>
#     <tr>
#       <th id="T_7d5a3_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_7d5a3_row2_col0" class="data row2 col0" >0.507092</td>
#       <td id="T_7d5a3_row2_col1" class="data row2 col1" >0.491489</td>
#       <td id="T_7d5a3_row2_col2" class="data row2 col2" >0.489362</td>
#       <td id="T_7d5a3_row2_col3" class="data row2 col3" >0.944657</td>
#       <td id="T_7d5a3_row2_col4" class="data row2 col4" >0.920885</td>
#       <td id="T_7d5a3_row2_col5" class="data row2 col5" >0.891620</td>
#     </tr>
#     <tr>
#       <th id="T_7d5a3_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_7d5a3_row3_col0" class="data row3 col0" >0.599291</td>
#       <td id="T_7d5a3_row3_col1" class="data row3 col1" >0.576596</td>
#       <td id="T_7d5a3_row3_col2" class="data row3 col2" >0.590426</td>
#       <td id="T_7d5a3_row3_col3" class="data row3 col3" >0.939337</td>
#       <td id="T_7d5a3_row3_col4" class="data row3 col4" >0.917686</td>
#       <td id="T_7d5a3_row3_col5" class="data row3 col5" >0.887910</td>
#     </tr>
#     <tr>
#       <th id="T_7d5a3_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_7d5a3_row4_col0" class="data row4 col0" >0.808511</td>
#       <td id="T_7d5a3_row4_col1" class="data row4 col1" >0.761702</td>
#       <td id="T_7d5a3_row4_col2" class="data row4 col2" >0.722340</td>
#       <td id="T_7d5a3_row4_col3" class="data row4 col3" >0.956565</td>
#       <td id="T_7d5a3_row4_col4" class="data row4 col4" >0.945786</td>
#       <td id="T_7d5a3_row4_col5" class="data row4 col5" >0.933756</td>
#     </tr>
#     <tr>
#       <th id="T_7d5a3_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_7d5a3_row5_col0" class="data row5 col0" >0.503546</td>
#       <td id="T_7d5a3_row5_col1" class="data row5 col1" >0.480851</td>
#       <td id="T_7d5a3_row5_col2" class="data row5 col2" >0.443617</td>
#       <td id="T_7d5a3_row5_col3" class="data row5 col3" >0.943614</td>
#       <td id="T_7d5a3_row5_col4" class="data row5 col4" >0.934459</td>
#       <td id="T_7d5a3_row5_col5" class="data row5 col5" >0.917112</td>
#     </tr>
#     <tr>
#       <th id="T_7d5a3_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_7d5a3_row6_col0" class="data row6 col0" >0.535461</td>
#       <td id="T_7d5a3_row6_col1" class="data row6 col1" >0.534043</td>
#       <td id="T_7d5a3_row6_col2" class="data row6 col2" >0.498936</td>
#       <td id="T_7d5a3_row6_col3" class="data row6 col3" >0.941560</td>
#       <td id="T_7d5a3_row6_col4" class="data row6 col4" >0.914002</td>
#       <td id="T_7d5a3_row6_col5" class="data row6 col5" >0.905112</td>
#     </tr>
#     <tr>
#       <th id="T_7d5a3_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_7d5a3_row7_col0" class="data row7 col0" >0.677305</td>
#       <td id="T_7d5a3_row7_col1" class="data row7 col1" >0.687234</td>
#       <td id="T_7d5a3_row7_col2" class="data row7 col2" >0.680851</td>
#       <td id="T_7d5a3_row7_col3" class="data row7 col3" >0.947572</td>
#       <td id="T_7d5a3_row7_col4" class="data row7 col4" >0.932023</td>
#       <td id="T_7d5a3_row7_col5" class="data row7 col5" >0.913666</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ----
#
# ### Heuristic predictions

# %% [markdown]
# **Least_descriptive queries** (10 evaluated generic queries)

# %%
least_df = create_precision_results_dataframe(model_variants, descriptiveness_level="least_descriptive", function_score="heuristic_scores")
least_df
# Out:
# <style type="text/css">
# #T_ef0b1 td:nth-child(4) {
#   border-right: 4px solid white;
# }
# #T_ef0b1 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_ef0b1_row0_col0, #T_ef0b1_row0_col1, #T_ef0b1_row2_col3, #T_ef0b1_row2_col4, #T_ef0b1_row2_col5, #T_ef0b1_row3_col0, #T_ef0b1_row3_col2, #T_ef0b1_row4_col3, #T_ef0b1_row4_col4, #T_ef0b1_row7_col0, #T_ef0b1_row7_col1, #T_ef0b1_row7_col2, #T_ef0b1_row7_col5 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# #T_ef0b1_row0_col2, #T_ef0b1_row1_col0, #T_ef0b1_row1_col3, #T_ef0b1_row1_col4, #T_ef0b1_row1_col5, #T_ef0b1_row2_col0, #T_ef0b1_row3_col1, #T_ef0b1_row4_col0, #T_ef0b1_row4_col1, #T_ef0b1_row4_col2, #T_ef0b1_row4_col5, #T_ef0b1_row7_col3, #T_ef0b1_row7_col4 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_ef0b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef0b1_level0_col0" class="col_heading level0 col0" >prec@3</th>
#       <th id="T_ef0b1_level0_col1" class="col_heading level0 col1" >prec@5</th>
#       <th id="T_ef0b1_level0_col2" class="col_heading level0 col2" >prec@10</th>
#       <th id="T_ef0b1_level0_col3" class="col_heading level0 col3" >ndcg@3</th>
#       <th id="T_ef0b1_level0_col4" class="col_heading level0 col4" >ndcg@5</th>
#       <th id="T_ef0b1_level0_col5" class="col_heading level0 col5" >ndcg@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef0b1_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_ef0b1_row0_col0" class="data row0 col0" >0.733333</td>
#       <td id="T_ef0b1_row0_col1" class="data row0 col1" >0.780000</td>
#       <td id="T_ef0b1_row0_col2" class="data row0 col2" >0.790000</td>
#       <td id="T_ef0b1_row0_col3" class="data row0 col3" >0.782470</td>
#       <td id="T_ef0b1_row0_col4" class="data row0 col4" >0.780608</td>
#       <td id="T_ef0b1_row0_col5" class="data row0 col5" >0.760539</td>
#     </tr>
#     <tr>
#       <th id="T_ef0b1_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_ef0b1_row1_col0" class="data row1 col0" >0.700000</td>
#       <td id="T_ef0b1_row1_col1" class="data row1 col1" >0.720000</td>
#       <td id="T_ef0b1_row1_col2" class="data row1 col2" >0.710000</td>
#       <td id="T_ef0b1_row1_col3" class="data row1 col3" >0.898420</td>
#       <td id="T_ef0b1_row1_col4" class="data row1 col4" >0.893156</td>
#       <td id="T_ef0b1_row1_col5" class="data row1 col5" >0.862875</td>
#     </tr>
#     <tr>
#       <th id="T_ef0b1_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_ef0b1_row2_col0" class="data row2 col0" >0.700000</td>
#       <td id="T_ef0b1_row2_col1" class="data row2 col1" >0.700000</td>
#       <td id="T_ef0b1_row2_col2" class="data row2 col2" >0.710000</td>
#       <td id="T_ef0b1_row2_col3" class="data row2 col3" >0.943353</td>
#       <td id="T_ef0b1_row2_col4" class="data row2 col4" >0.917547</td>
#       <td id="T_ef0b1_row2_col5" class="data row2 col5" >0.883177</td>
#     </tr>
#     <tr>
#       <th id="T_ef0b1_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_ef0b1_row3_col0" class="data row3 col0" >0.733333</td>
#       <td id="T_ef0b1_row3_col1" class="data row3 col1" >0.740000</td>
#       <td id="T_ef0b1_row3_col2" class="data row3 col2" >0.800000</td>
#       <td id="T_ef0b1_row3_col3" class="data row3 col3" >0.805183</td>
#       <td id="T_ef0b1_row3_col4" class="data row3 col4" >0.814949</td>
#       <td id="T_ef0b1_row3_col5" class="data row3 col5" >0.824731</td>
#     </tr>
#     <tr>
#       <th id="T_ef0b1_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_ef0b1_row4_col0" class="data row4 col0" >0.866667</td>
#       <td id="T_ef0b1_row4_col1" class="data row4 col1" >0.880000</td>
#       <td id="T_ef0b1_row4_col2" class="data row4 col2" >0.890000</td>
#       <td id="T_ef0b1_row4_col3" class="data row4 col3" >0.934847</td>
#       <td id="T_ef0b1_row4_col4" class="data row4 col4" >0.911381</td>
#       <td id="T_ef0b1_row4_col5" class="data row4 col5" >0.875902</td>
#     </tr>
#     <tr>
#       <th id="T_ef0b1_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_ef0b1_row5_col0" class="data row5 col0" >0.666667</td>
#       <td id="T_ef0b1_row5_col1" class="data row5 col1" >0.660000</td>
#       <td id="T_ef0b1_row5_col2" class="data row5 col2" >0.590000</td>
#       <td id="T_ef0b1_row5_col3" class="data row5 col3" >0.736219</td>
#       <td id="T_ef0b1_row5_col4" class="data row5 col4" >0.739891</td>
#       <td id="T_ef0b1_row5_col5" class="data row5 col5" >0.736146</td>
#     </tr>
#     <tr>
#       <th id="T_ef0b1_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_ef0b1_row6_col0" class="data row6 col0" >0.566667</td>
#       <td id="T_ef0b1_row6_col1" class="data row6 col1" >0.580000</td>
#       <td id="T_ef0b1_row6_col2" class="data row6 col2" >0.650000</td>
#       <td id="T_ef0b1_row6_col3" class="data row6 col3" >0.790439</td>
#       <td id="T_ef0b1_row6_col4" class="data row6 col4" >0.826773</td>
#       <td id="T_ef0b1_row6_col5" class="data row6 col5" >0.799051</td>
#     </tr>
#     <tr>
#       <th id="T_ef0b1_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_ef0b1_row7_col0" class="data row7 col0" >0.933333</td>
#       <td id="T_ef0b1_row7_col1" class="data row7 col1" >0.900000</td>
#       <td id="T_ef0b1_row7_col2" class="data row7 col2" >0.900000</td>
#       <td id="T_ef0b1_row7_col3" class="data row7 col3" >0.913543</td>
#       <td id="T_ef0b1_row7_col4" class="data row7 col4" >0.898612</td>
#       <td id="T_ef0b1_row7_col5" class="data row7 col5" >0.899889</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Moderately_descriptive queries** (30 evaluated generic queries)

# %%
moderate_df = create_precision_results_dataframe(model_variants, descriptiveness_level="moderately_descriptive", function_score="heuristic_scores")
moderate_df
# Out:
# <style type="text/css">
# #T_9e359 td:nth-child(4) {
#   border-right: 4px solid white;
# }
# #T_9e359 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_9e359_row0_col0, #T_9e359_row0_col1, #T_9e359_row0_col2, #T_9e359_row0_col3, #T_9e359_row0_col4, #T_9e359_row0_col5, #T_9e359_row4_col0, #T_9e359_row4_col1, #T_9e359_row4_col2, #T_9e359_row4_col3, #T_9e359_row4_col4, #T_9e359_row4_col5 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# #T_9e359_row2_col3, #T_9e359_row2_col4, #T_9e359_row2_col5, #T_9e359_row3_col0, #T_9e359_row3_col1, #T_9e359_row3_col2, #T_9e359_row6_col4, #T_9e359_row6_col5, #T_9e359_row7_col0, #T_9e359_row7_col1, #T_9e359_row7_col2, #T_9e359_row7_col3 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_9e359">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e359_level0_col0" class="col_heading level0 col0" >prec@3</th>
#       <th id="T_9e359_level0_col1" class="col_heading level0 col1" >prec@5</th>
#       <th id="T_9e359_level0_col2" class="col_heading level0 col2" >prec@10</th>
#       <th id="T_9e359_level0_col3" class="col_heading level0 col3" >ndcg@3</th>
#       <th id="T_9e359_level0_col4" class="col_heading level0 col4" >ndcg@5</th>
#       <th id="T_9e359_level0_col5" class="col_heading level0 col5" >ndcg@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e359_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_9e359_row0_col0" class="data row0 col0" >0.866667</td>
#       <td id="T_9e359_row0_col1" class="data row0 col1" >0.813333</td>
#       <td id="T_9e359_row0_col2" class="data row0 col2" >0.770000</td>
#       <td id="T_9e359_row0_col3" class="data row0 col3" >0.950458</td>
#       <td id="T_9e359_row0_col4" class="data row0 col4" >0.922393</td>
#       <td id="T_9e359_row0_col5" class="data row0 col5" >0.881324</td>
#     </tr>
#     <tr>
#       <th id="T_9e359_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_9e359_row1_col0" class="data row1 col0" >0.488889</td>
#       <td id="T_9e359_row1_col1" class="data row1 col1" >0.506667</td>
#       <td id="T_9e359_row1_col2" class="data row1 col2" >0.480000</td>
#       <td id="T_9e359_row1_col3" class="data row1 col3" >0.861554</td>
#       <td id="T_9e359_row1_col4" class="data row1 col4" >0.819019</td>
#       <td id="T_9e359_row1_col5" class="data row1 col5" >0.819698</td>
#     </tr>
#     <tr>
#       <th id="T_9e359_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_9e359_row2_col0" class="data row2 col0" >0.622222</td>
#       <td id="T_9e359_row2_col1" class="data row2 col1" >0.573333</td>
#       <td id="T_9e359_row2_col2" class="data row2 col2" >0.546667</td>
#       <td id="T_9e359_row2_col3" class="data row2 col3" >0.890512</td>
#       <td id="T_9e359_row2_col4" class="data row2 col4" >0.874402</td>
#       <td id="T_9e359_row2_col5" class="data row2 col5" >0.843532</td>
#     </tr>
#     <tr>
#       <th id="T_9e359_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_9e359_row3_col0" class="data row3 col0" >0.644444</td>
#       <td id="T_9e359_row3_col1" class="data row3 col1" >0.620000</td>
#       <td id="T_9e359_row3_col2" class="data row3 col2" >0.620000</td>
#       <td id="T_9e359_row3_col3" class="data row3 col3" >0.875908</td>
#       <td id="T_9e359_row3_col4" class="data row3 col4" >0.857962</td>
#       <td id="T_9e359_row3_col5" class="data row3 col5" >0.817924</td>
#     </tr>
#     <tr>
#       <th id="T_9e359_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_9e359_row4_col0" class="data row4 col0" >0.822222</td>
#       <td id="T_9e359_row4_col1" class="data row4 col1" >0.780000</td>
#       <td id="T_9e359_row4_col2" class="data row4 col2" >0.756667</td>
#       <td id="T_9e359_row4_col3" class="data row4 col3" >0.951764</td>
#       <td id="T_9e359_row4_col4" class="data row4 col4" >0.931141</td>
#       <td id="T_9e359_row4_col5" class="data row4 col5" >0.902206</td>
#     </tr>
#     <tr>
#       <th id="T_9e359_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_9e359_row5_col0" class="data row5 col0" >0.600000</td>
#       <td id="T_9e359_row5_col1" class="data row5 col1" >0.533333</td>
#       <td id="T_9e359_row5_col2" class="data row5 col2" >0.480000</td>
#       <td id="T_9e359_row5_col3" class="data row5 col3" >0.888735</td>
#       <td id="T_9e359_row5_col4" class="data row5 col4" >0.875225</td>
#       <td id="T_9e359_row5_col5" class="data row5 col5" >0.854429</td>
#     </tr>
#     <tr>
#       <th id="T_9e359_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_9e359_row6_col0" class="data row6 col0" >0.577778</td>
#       <td id="T_9e359_row6_col1" class="data row6 col1" >0.533333</td>
#       <td id="T_9e359_row6_col2" class="data row6 col2" >0.516667</td>
#       <td id="T_9e359_row6_col3" class="data row6 col3" >0.919225</td>
#       <td id="T_9e359_row6_col4" class="data row6 col4" >0.906729</td>
#       <td id="T_9e359_row6_col5" class="data row6 col5" >0.884359</td>
#     </tr>
#     <tr>
#       <th id="T_9e359_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_9e359_row7_col0" class="data row7 col0" >0.677778</td>
#       <td id="T_9e359_row7_col1" class="data row7 col1" >0.726667</td>
#       <td id="T_9e359_row7_col2" class="data row7 col2" >0.713333</td>
#       <td id="T_9e359_row7_col3" class="data row7 col3" >0.920551</td>
#       <td id="T_9e359_row7_col4" class="data row7 col4" >0.896629</td>
#       <td id="T_9e359_row7_col5" class="data row7 col5" >0.870544</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Most_descriptive queries** (50 evaluated generic queries)

# %%
most_df = create_precision_results_dataframe(model_variants, descriptiveness_level="most_descriptive", function_score="heuristic_scores")
most_df
# Out:
# <style type="text/css">
# #T_bcd83 td:nth-child(4) {
#   border-right: 4px solid white;
# }
# #T_bcd83 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_bcd83_row0_col0, #T_bcd83_row0_col1, #T_bcd83_row0_col2, #T_bcd83_row3_col3, #T_bcd83_row3_col4, #T_bcd83_row3_col5, #T_bcd83_row4_col0, #T_bcd83_row4_col1, #T_bcd83_row4_col2, #T_bcd83_row7_col3, #T_bcd83_row7_col4, #T_bcd83_row7_col5 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# #T_bcd83_row0_col5, #T_bcd83_row2_col3, #T_bcd83_row2_col4, #T_bcd83_row3_col0, #T_bcd83_row3_col1, #T_bcd83_row3_col2, #T_bcd83_row4_col3, #T_bcd83_row4_col4, #T_bcd83_row4_col5, #T_bcd83_row7_col0, #T_bcd83_row7_col1, #T_bcd83_row7_col2 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_bcd83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcd83_level0_col0" class="col_heading level0 col0" >prec@3</th>
#       <th id="T_bcd83_level0_col1" class="col_heading level0 col1" >prec@5</th>
#       <th id="T_bcd83_level0_col2" class="col_heading level0 col2" >prec@10</th>
#       <th id="T_bcd83_level0_col3" class="col_heading level0 col3" >ndcg@3</th>
#       <th id="T_bcd83_level0_col4" class="col_heading level0 col4" >ndcg@5</th>
#       <th id="T_bcd83_level0_col5" class="col_heading level0 col5" >ndcg@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcd83_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_bcd83_row0_col0" class="data row0 col0" >0.462963</td>
#       <td id="T_bcd83_row0_col1" class="data row0 col1" >0.414815</td>
#       <td id="T_bcd83_row0_col2" class="data row0 col2" >0.370370</td>
#       <td id="T_bcd83_row0_col3" class="data row0 col3" >0.810439</td>
#       <td id="T_bcd83_row0_col4" class="data row0 col4" >0.793206</td>
#       <td id="T_bcd83_row0_col5" class="data row0 col5" >0.788892</td>
#     </tr>
#     <tr>
#       <th id="T_bcd83_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_bcd83_row1_col0" class="data row1 col0" >0.271605</td>
#       <td id="T_bcd83_row1_col1" class="data row1 col1" >0.285185</td>
#       <td id="T_bcd83_row1_col2" class="data row1 col2" >0.257407</td>
#       <td id="T_bcd83_row1_col3" class="data row1 col3" >0.786210</td>
#       <td id="T_bcd83_row1_col4" class="data row1 col4" >0.779858</td>
#       <td id="T_bcd83_row1_col5" class="data row1 col5" >0.777268</td>
#     </tr>
#     <tr>
#       <th id="T_bcd83_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_bcd83_row2_col0" class="data row2 col0" >0.253086</td>
#       <td id="T_bcd83_row2_col1" class="data row2 col1" >0.277778</td>
#       <td id="T_bcd83_row2_col2" class="data row2 col2" >0.262963</td>
#       <td id="T_bcd83_row2_col3" class="data row2 col3" >0.828089</td>
#       <td id="T_bcd83_row2_col4" class="data row2 col4" >0.810527</td>
#       <td id="T_bcd83_row2_col5" class="data row2 col5" >0.778892</td>
#     </tr>
#     <tr>
#       <th id="T_bcd83_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_bcd83_row3_col0" class="data row3 col0" >0.345679</td>
#       <td id="T_bcd83_row3_col1" class="data row3 col1" >0.329630</td>
#       <td id="T_bcd83_row3_col2" class="data row3 col2" >0.346296</td>
#       <td id="T_bcd83_row3_col3" class="data row3 col3" >0.867957</td>
#       <td id="T_bcd83_row3_col4" class="data row3 col4" >0.850223</td>
#       <td id="T_bcd83_row3_col5" class="data row3 col5" >0.815994</td>
#     </tr>
#     <tr>
#       <th id="T_bcd83_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_bcd83_row4_col0" class="data row4 col0" >0.592593</td>
#       <td id="T_bcd83_row4_col1" class="data row4 col1" >0.548148</td>
#       <td id="T_bcd83_row4_col2" class="data row4 col2" >0.501852</td>
#       <td id="T_bcd83_row4_col3" class="data row4 col3" >0.899618</td>
#       <td id="T_bcd83_row4_col4" class="data row4 col4" >0.880512</td>
#       <td id="T_bcd83_row4_col5" class="data row4 col5" >0.858624</td>
#     </tr>
#     <tr>
#       <th id="T_bcd83_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_bcd83_row5_col0" class="data row5 col0" >0.351852</td>
#       <td id="T_bcd83_row5_col1" class="data row5 col1" >0.325926</td>
#       <td id="T_bcd83_row5_col2" class="data row5 col2" >0.309259</td>
#       <td id="T_bcd83_row5_col3" class="data row5 col3" >0.826988</td>
#       <td id="T_bcd83_row5_col4" class="data row5 col4" >0.817029</td>
#       <td id="T_bcd83_row5_col5" class="data row5 col5" >0.796365</td>
#     </tr>
#     <tr>
#       <th id="T_bcd83_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_bcd83_row6_col0" class="data row6 col0" >0.314815</td>
#       <td id="T_bcd83_row6_col1" class="data row6 col1" >0.311111</td>
#       <td id="T_bcd83_row6_col2" class="data row6 col2" >0.275926</td>
#       <td id="T_bcd83_row6_col3" class="data row6 col3" >0.855410</td>
#       <td id="T_bcd83_row6_col4" class="data row6 col4" >0.827598</td>
#       <td id="T_bcd83_row6_col5" class="data row6 col5" >0.806311</td>
#     </tr>
#     <tr>
#       <th id="T_bcd83_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_bcd83_row7_col0" class="data row7 col0" >0.506173</td>
#       <td id="T_bcd83_row7_col1" class="data row7 col1" >0.496296</td>
#       <td id="T_bcd83_row7_col2" class="data row7 col2" >0.487037</td>
#       <td id="T_bcd83_row7_col3" class="data row7 col3" >0.902635</td>
#       <td id="T_bcd83_row7_col4" class="data row7 col4" >0.891687</td>
#       <td id="T_bcd83_row7_col5" class="data row7 col5" >0.874122</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **All queries** (90 queries)

# %%
all_df = create_precision_results_dataframe(model_variants, descriptiveness_level="all", function_score="heuristic_scores")
all_df
# Out:
# <style type="text/css">
# #T_cdbfb td:nth-child(4) {
#   border-right: 4px solid white;
# }
# #T_cdbfb tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_cdbfb_row0_col0, #T_cdbfb_row0_col1, #T_cdbfb_row0_col2, #T_cdbfb_row3_col3, #T_cdbfb_row3_col4, #T_cdbfb_row3_col5, #T_cdbfb_row4_col0, #T_cdbfb_row4_col1, #T_cdbfb_row4_col2, #T_cdbfb_row4_col3, #T_cdbfb_row4_col4, #T_cdbfb_row7_col5 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# #T_cdbfb_row0_col5, #T_cdbfb_row2_col3, #T_cdbfb_row2_col4, #T_cdbfb_row3_col0, #T_cdbfb_row3_col1, #T_cdbfb_row3_col2, #T_cdbfb_row4_col5, #T_cdbfb_row7_col0, #T_cdbfb_row7_col1, #T_cdbfb_row7_col2, #T_cdbfb_row7_col3, #T_cdbfb_row7_col4 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_cdbfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdbfb_level0_col0" class="col_heading level0 col0" >prec@3</th>
#       <th id="T_cdbfb_level0_col1" class="col_heading level0 col1" >prec@5</th>
#       <th id="T_cdbfb_level0_col2" class="col_heading level0 col2" >prec@10</th>
#       <th id="T_cdbfb_level0_col3" class="col_heading level0 col3" >ndcg@3</th>
#       <th id="T_cdbfb_level0_col4" class="col_heading level0 col4" >ndcg@5</th>
#       <th id="T_cdbfb_level0_col5" class="col_heading level0 col5" >ndcg@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdbfb_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_cdbfb_row0_col0" class="data row0 col0" >0.620567</td>
#       <td id="T_cdbfb_row0_col1" class="data row0 col1" >0.580851</td>
#       <td id="T_cdbfb_row0_col2" class="data row0 col2" >0.542553</td>
#       <td id="T_cdbfb_row0_col3" class="data row0 col3" >0.852151</td>
#       <td id="T_cdbfb_row0_col4" class="data row0 col4" >0.833096</td>
#       <td id="T_cdbfb_row0_col5" class="data row0 col5" >0.815375</td>
#     </tr>
#     <tr>
#       <th id="T_cdbfb_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_cdbfb_row1_col0" class="data row1 col0" >0.386525</td>
#       <td id="T_cdbfb_row1_col1" class="data row1 col1" >0.402128</td>
#       <td id="T_cdbfb_row1_col2" class="data row1 col2" >0.376596</td>
#       <td id="T_cdbfb_row1_col3" class="data row1 col3" >0.822193</td>
#       <td id="T_cdbfb_row1_col4" class="data row1 col4" >0.804410</td>
#       <td id="T_cdbfb_row1_col5" class="data row1 col5" >0.799917</td>
#     </tr>
#     <tr>
#       <th id="T_cdbfb_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_cdbfb_row2_col0" class="data row2 col0" >0.418440</td>
#       <td id="T_cdbfb_row2_col1" class="data row2 col1" >0.417021</td>
#       <td id="T_cdbfb_row2_col2" class="data row2 col2" >0.401064</td>
#       <td id="T_cdbfb_row2_col3" class="data row2 col3" >0.860273</td>
#       <td id="T_cdbfb_row2_col4" class="data row2 col4" >0.842298</td>
#       <td id="T_cdbfb_row2_col5" class="data row2 col5" >0.810616</td>
#     </tr>
#     <tr>
#       <th id="T_cdbfb_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_cdbfb_row3_col0" class="data row3 col0" >0.482270</td>
#       <td id="T_cdbfb_row3_col1" class="data row3 col1" >0.465957</td>
#       <td id="T_cdbfb_row3_col2" class="data row3 col2" >0.481915</td>
#       <td id="T_cdbfb_row3_col3" class="data row3 col3" >0.863816</td>
#       <td id="T_cdbfb_row3_col4" class="data row3 col4" >0.848940</td>
#       <td id="T_cdbfb_row3_col5" class="data row3 col5" >0.817540</td>
#     </tr>
#     <tr>
#       <th id="T_cdbfb_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_cdbfb_row4_col0" class="data row4 col0" >0.695035</td>
#       <td id="T_cdbfb_row4_col1" class="data row4 col1" >0.657447</td>
#       <td id="T_cdbfb_row4_col2" class="data row4 col2" >0.624468</td>
#       <td id="T_cdbfb_row4_col3" class="data row4 col3" >0.920008</td>
#       <td id="T_cdbfb_row4_col4" class="data row4 col4" >0.899954</td>
#       <td id="T_cdbfb_row4_col5" class="data row4 col5" >0.874371</td>
#     </tr>
#     <tr>
#       <th id="T_cdbfb_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_cdbfb_row5_col0" class="data row5 col0" >0.464539</td>
#       <td id="T_cdbfb_row5_col1" class="data row5 col1" >0.427660</td>
#       <td id="T_cdbfb_row5_col2" class="data row5 col2" >0.393617</td>
#       <td id="T_cdbfb_row5_col3" class="data row5 col3" >0.837038</td>
#       <td id="T_cdbfb_row5_col4" class="data row5 col4" >0.827396</td>
#       <td id="T_cdbfb_row5_col5" class="data row5 col5" >0.808490</td>
#     </tr>
#     <tr>
#       <th id="T_cdbfb_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_cdbfb_row6_col0" class="data row6 col0" >0.425532</td>
#       <td id="T_cdbfb_row6_col1" class="data row6 col1" >0.410638</td>
#       <td id="T_cdbfb_row6_col2" class="data row6 col2" >0.392553</td>
#       <td id="T_cdbfb_row6_col3" class="data row6 col3" >0.868865</td>
#       <td id="T_cdbfb_row6_col4" class="data row6 col4" >0.852765</td>
#       <td id="T_cdbfb_row6_col5" class="data row6 col5" >0.830448</td>
#     </tr>
#     <tr>
#       <th id="T_cdbfb_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_cdbfb_row7_col0" class="data row7 col0" >0.606383</td>
#       <td id="T_cdbfb_row7_col1" class="data row7 col1" >0.612766</td>
#       <td id="T_cdbfb_row7_col2" class="data row7 col2" >0.603191</td>
#       <td id="T_cdbfb_row7_col3" class="data row7 col3" >0.909513</td>
#       <td id="T_cdbfb_row7_col4" class="data row7 col4" >0.894001</td>
#       <td id="T_cdbfb_row7_col5" class="data row7 col5" >0.875721</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Precision evaluation conclusion
#
# - <span style="color:red">GTE model is the best</span>, 2nd best being BGE model
#     - E5 models performed the worst
#
# - Use of chunk embedding instead of document embeddings for E5 model improves the performance, but not that singificantly
#
# - Best field extraction technique
#     - on average, <span style="color:red">RELEVANT > BASIC</span>
#     - for moderately long descriptions: BASIC > RELEVANT
#     - for long descriptions: RELEVANT > BASIC
#
# - **Use of both LLM predicitions and heuristic predictions led to the same conclusions**

# %% [markdown]
# -----
# -----
# -----

# %% [markdown]
# # Accuracy/Hit-rate evaluation
#
# - Retrieve top K (K=100) most similar documents to the **ASSET-SPECIFIC QUERIES**
# - Check the existence and the position of the GROUND TRUTH assets that correspond to the individual queries
# - Compute metrics

# %%
def highlight_hitrate(s: pd.Series):
    is_max = s == s.max()
    is_second_max = s == sorted(s.unique())[-2] if len(s.unique()) > 1 else s == s.max()
    return ['background-color: rgba(255, 0, 0, 0.3); color: white' if v else 'background-color: rgba(255, 165, 0, 0.3); color: white' if is_second_max[idx] else '' for idx, v in is_max.items()]

def highlight_hit_position(s: pd.Series):
    is_min = s == s.min()
    is_second_min = s == sorted(s.unique())[1] if len(s.unique()) > 1 else s == s.min()
    return ['background-color: rgba(255, 0, 0, 0.3); color: white' if v else 'background-color: rgba(255, 165, 0, 0.3); color: white' if is_second_min[idx] else '' for idx, v in is_min.items()]

# %%
def create_hitrate_results_dataframe(
    model_variants: list[str], 
    asset_quality: Literal["long_description_few_tags", "long_description_many_tags", "moderate_description_many_tags", "poor_description_many_tags", "all"] = "all", 
    descriptiveness_level: Literal["least_descriptive", "moderately_descriptive", "most_descriptive", "all"] = "all", 

) -> pd.DataFrame:
    precision_results_path = "data/results/hit_rate"
    metric_col_names = [
        "asset_hit_rate@5", "asset_hit_rate@10", "asset_hit_rate@20", "asset_hit_rate@30",
        "asset_position@5", "asset_position@10", "asset_position@20", "asset_position@30",
    ]
    dataframe_rows = [[] for _ in range(len(model_variants))]
    for it_var, var in enumerate(model_variants):
        if asset_quality == "all" and descriptiveness_level == "all":
            path = os.path.join(
                precision_results_path, var, "all", "results.json"
            )
        elif asset_quality == "all":
            path = os.path.join(
                precision_results_path, var, descriptiveness_level, "results.json"
            )
        elif descriptiveness_level == "all":
            path = os.path.join(
                precision_results_path, var, asset_quality, "results.json"
            )
        else:
            path = os.path.join(
                precision_results_path, var, 
                f"{descriptiveness_level}-{asset_quality}",
                "results.json"
            )
            
        with open(path) as f:
            metrics = SpecificAssetQueriesMetrics.load(json.load(f))
        
        dataframe_rows[it_var].append(var)
        for col_name in metric_col_names:
            m_name, k = col_name.split("@")
            m_value = getattr(metrics.results_in_top[k], m_name)
            dataframe_rows[it_var].append(m_value)    
        
    df = pd.DataFrame(data=dataframe_rows, columns=["Input Config"] + metric_col_names)
    df = df.set_index(keys=["Input Config"], drop=True)

    cols = df.columns
    index_values = df.index.values
        
    df = df.style.apply(highlight_hitrate, subset=pd.IndexSlice[index_values[: len(df.index) // 2], cols[: len(cols) // 2]])
    df = df.apply(highlight_hitrate, subset=pd.IndexSlice[index_values[len(df.index) // 2:], cols[: len(cols) // 2]])

    df = df.apply(highlight_hit_position, subset=pd.IndexSlice[index_values[: len(df.index) // 2], cols[len(cols) // 2:]])
    df = df.apply(highlight_hit_position, subset=pd.IndexSlice[index_values[len(df.index) // 2:], cols[len(cols) // 2:]])

    df = add_middle_border(df)
    return df

# %% [markdown]
# ## Analyzing individual pairs (asset_quality, descriptiveness level) on retrieval performance

# %% [markdown]
# #### Assets with long descriptions (50 assets)
# - description with over 1000 characters

# %%
long_doc_least_df = create_hitrate_results_dataframe(model_variants, asset_quality="long_description_many_tags", descriptiveness_level="least_descriptive")
long_doc_least_df
# Out:
# <style type="text/css">
# #T_b81b0 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_b81b0 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_b81b0_row0_col0, #T_b81b0_row0_col1, #T_b81b0_row0_col3, #T_b81b0_row1_col7, #T_b81b0_row2_col1, #T_b81b0_row2_col2, #T_b81b0_row2_col3, #T_b81b0_row3_col4, #T_b81b0_row3_col5, #T_b81b0_row3_col6, #T_b81b0_row4_col0, #T_b81b0_row4_col1, #T_b81b0_row4_col2, #T_b81b0_row4_col4, #T_b81b0_row4_col5, #T_b81b0_row6_col3, #T_b81b0_row7_col6, #T_b81b0_row7_col7 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_b81b0_row0_col4, #T_b81b0_row0_col5, #T_b81b0_row0_col6, #T_b81b0_row0_col7, #T_b81b0_row3_col0, #T_b81b0_row3_col1, #T_b81b0_row3_col2, #T_b81b0_row3_col3, #T_b81b0_row4_col6, #T_b81b0_row4_col7, #T_b81b0_row5_col4, #T_b81b0_row5_col5, #T_b81b0_row7_col0, #T_b81b0_row7_col1, #T_b81b0_row7_col2, #T_b81b0_row7_col3 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_b81b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b81b0_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_b81b0_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_b81b0_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_b81b0_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_b81b0_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_b81b0_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_b81b0_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_b81b0_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b81b0_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_b81b0_row0_col0" class="data row0 col0" >0.820000</td>
#       <td id="T_b81b0_row0_col1" class="data row0 col1" >0.820000</td>
#       <td id="T_b81b0_row0_col2" class="data row0 col2" >0.840000</td>
#       <td id="T_b81b0_row0_col3" class="data row0 col3" >0.860000</td>
#       <td id="T_b81b0_row0_col4" class="data row0 col4" >0.536585</td>
#       <td id="T_b81b0_row0_col5" class="data row0 col5" >0.536585</td>
#       <td id="T_b81b0_row0_col6" class="data row0 col6" >0.785714</td>
#       <td id="T_b81b0_row0_col7" class="data row0 col7" >1.372093</td>
#     </tr>
#     <tr>
#       <th id="T_b81b0_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_b81b0_row1_col0" class="data row1 col0" >0.660000</td>
#       <td id="T_b81b0_row1_col1" class="data row1 col1" >0.720000</td>
#       <td id="T_b81b0_row1_col2" class="data row1 col2" >0.740000</td>
#       <td id="T_b81b0_row1_col3" class="data row1 col3" >0.740000</td>
#       <td id="T_b81b0_row1_col4" class="data row1 col4" >0.787879</td>
#       <td id="T_b81b0_row1_col5" class="data row1 col5" >1.361111</td>
#       <td id="T_b81b0_row1_col6" class="data row1 col6" >1.675676</td>
#       <td id="T_b81b0_row1_col7" class="data row1 col7" >1.675676</td>
#     </tr>
#     <tr>
#       <th id="T_b81b0_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_b81b0_row2_col0" class="data row2 col0" >0.700000</td>
#       <td id="T_b81b0_row2_col1" class="data row2 col1" >0.820000</td>
#       <td id="T_b81b0_row2_col2" class="data row2 col2" >0.860000</td>
#       <td id="T_b81b0_row2_col3" class="data row2 col3" >0.860000</td>
#       <td id="T_b81b0_row2_col4" class="data row2 col4" >0.771429</td>
#       <td id="T_b81b0_row2_col5" class="data row2 col5" >1.682927</td>
#       <td id="T_b81b0_row2_col6" class="data row2 col6" >2.279070</td>
#       <td id="T_b81b0_row2_col7" class="data row2 col7" >2.279070</td>
#     </tr>
#     <tr>
#       <th id="T_b81b0_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_b81b0_row3_col0" class="data row3 col0" >0.840000</td>
#       <td id="T_b81b0_row3_col1" class="data row3 col1" >0.940000</td>
#       <td id="T_b81b0_row3_col2" class="data row3 col2" >0.940000</td>
#       <td id="T_b81b0_row3_col3" class="data row3 col3" >0.980000</td>
#       <td id="T_b81b0_row3_col4" class="data row3 col4" >0.571429</td>
#       <td id="T_b81b0_row3_col5" class="data row3 col5" >1.191489</td>
#       <td id="T_b81b0_row3_col6" class="data row3 col6" >1.191489</td>
#       <td id="T_b81b0_row3_col7" class="data row3 col7" >2.204082</td>
#     </tr>
#     <tr>
#       <th id="T_b81b0_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_b81b0_row4_col0" class="data row4 col0" >0.800000</td>
#       <td id="T_b81b0_row4_col1" class="data row4 col1" >0.840000</td>
#       <td id="T_b81b0_row4_col2" class="data row4 col2" >0.840000</td>
#       <td id="T_b81b0_row4_col3" class="data row4 col3" >0.840000</td>
#       <td id="T_b81b0_row4_col4" class="data row4 col4" >0.500000</td>
#       <td id="T_b81b0_row4_col5" class="data row4 col5" >0.809524</td>
#       <td id="T_b81b0_row4_col6" class="data row4 col6" >0.809524</td>
#       <td id="T_b81b0_row4_col7" class="data row4 col7" >0.809524</td>
#     </tr>
#     <tr>
#       <th id="T_b81b0_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_b81b0_row5_col0" class="data row5 col0" >0.340000</td>
#       <td id="T_b81b0_row5_col1" class="data row5 col1" >0.340000</td>
#       <td id="T_b81b0_row5_col2" class="data row5 col2" >0.380000</td>
#       <td id="T_b81b0_row5_col3" class="data row5 col3" >0.380000</td>
#       <td id="T_b81b0_row5_col4" class="data row5 col4" >0.470588</td>
#       <td id="T_b81b0_row5_col5" class="data row5 col5" >0.470588</td>
#       <td id="T_b81b0_row5_col6" class="data row5 col6" >1.894737</td>
#       <td id="T_b81b0_row5_col7" class="data row5 col7" >1.894737</td>
#     </tr>
#     <tr>
#       <th id="T_b81b0_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_b81b0_row6_col0" class="data row6 col0" >0.700000</td>
#       <td id="T_b81b0_row6_col1" class="data row6 col1" >0.720000</td>
#       <td id="T_b81b0_row6_col2" class="data row6 col2" >0.820000</td>
#       <td id="T_b81b0_row6_col3" class="data row6 col3" >0.860000</td>
#       <td id="T_b81b0_row6_col4" class="data row6 col4" >0.914286</td>
#       <td id="T_b81b0_row6_col5" class="data row6 col5" >1.055556</td>
#       <td id="T_b81b0_row6_col6" class="data row6 col6" >2.609756</td>
#       <td id="T_b81b0_row6_col7" class="data row6 col7" >3.697674</td>
#     </tr>
#     <tr>
#       <th id="T_b81b0_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_b81b0_row7_col0" class="data row7 col0" >0.880000</td>
#       <td id="T_b81b0_row7_col1" class="data row7 col1" >0.940000</td>
#       <td id="T_b81b0_row7_col2" class="data row7 col2" >0.940000</td>
#       <td id="T_b81b0_row7_col3" class="data row7 col3" >0.960000</td>
#       <td id="T_b81b0_row7_col4" class="data row7 col4" >0.613636</td>
#       <td id="T_b81b0_row7_col5" class="data row7 col5" >1.042553</td>
#       <td id="T_b81b0_row7_col6" class="data row7 col6" >1.042553</td>
#       <td id="T_b81b0_row7_col7" class="data row7 col7" >1.562500</td>
#     </tr>
#   </tbody>
# </table>

# %%
long_doc_moderate_df = create_hitrate_results_dataframe(model_variants, asset_quality="long_description_many_tags", descriptiveness_level="moderately_descriptive")
long_doc_moderate_df
# Out:
# <style type="text/css">
# #T_1740f td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_1740f tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_1740f_row0_col1, #T_1740f_row0_col4, #T_1740f_row0_col6, #T_1740f_row0_col7, #T_1740f_row1_col5, #T_1740f_row2_col0, #T_1740f_row2_col1, #T_1740f_row2_col2, #T_1740f_row2_col3, #T_1740f_row4_col0, #T_1740f_row4_col1, #T_1740f_row4_col2, #T_1740f_row4_col3, #T_1740f_row4_col4, #T_1740f_row4_col5, #T_1740f_row6_col3, #T_1740f_row7_col6, #T_1740f_row7_col7 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_1740f_row3_col0, #T_1740f_row3_col1, #T_1740f_row3_col2, #T_1740f_row3_col3, #T_1740f_row3_col4, #T_1740f_row3_col5, #T_1740f_row3_col6, #T_1740f_row3_col7, #T_1740f_row5_col4, #T_1740f_row5_col5, #T_1740f_row5_col6, #T_1740f_row5_col7, #T_1740f_row7_col0, #T_1740f_row7_col1, #T_1740f_row7_col2, #T_1740f_row7_col3 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_1740f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1740f_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_1740f_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_1740f_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_1740f_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_1740f_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_1740f_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_1740f_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_1740f_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1740f_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_1740f_row0_col0" class="data row0 col0" >0.800000</td>
#       <td id="T_1740f_row0_col1" class="data row0 col1" >0.860000</td>
#       <td id="T_1740f_row0_col2" class="data row0 col2" >0.880000</td>
#       <td id="T_1740f_row0_col3" class="data row0 col3" >0.880000</td>
#       <td id="T_1740f_row0_col4" class="data row0 col4" >0.325000</td>
#       <td id="T_1740f_row0_col5" class="data row0 col5" >0.697674</td>
#       <td id="T_1740f_row0_col6" class="data row0 col6" >0.909091</td>
#       <td id="T_1740f_row0_col7" class="data row0 col7" >0.909091</td>
#     </tr>
#     <tr>
#       <th id="T_1740f_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_1740f_row1_col0" class="data row1 col0" >0.680000</td>
#       <td id="T_1740f_row1_col1" class="data row1 col1" >0.720000</td>
#       <td id="T_1740f_row1_col2" class="data row1 col2" >0.780000</td>
#       <td id="T_1740f_row1_col3" class="data row1 col3" >0.800000</td>
#       <td id="T_1740f_row1_col4" class="data row1 col4" >0.352941</td>
#       <td id="T_1740f_row1_col5" class="data row1 col5" >0.611111</td>
#       <td id="T_1740f_row1_col6" class="data row1 col6" >1.589744</td>
#       <td id="T_1740f_row1_col7" class="data row1 col7" >2.075000</td>
#     </tr>
#     <tr>
#       <th id="T_1740f_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_
td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_0d860 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_0d860_row0_col0, #T_0d860_row0_col5, #T_0d860_row0_col6, #T_0d860_row0_col7, #T_0d860_row2_col1, #T_0d860_row2_col2, #T_0d860_row2_col3, #T_0d860_row2_col4, #T_0d860_row3_col4, #T_0d860_row4_col0, #T_0d860_row4_col2, #T_0d860_row4_col3, #T_0d860_row5_col4, #T_0d860_row5_col6, #T_0d860_row6_col1, #T_0d860_row6_col5, #T_0d860_row6_col7, #T_0d860_row7_col6 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_0d860_row0_col4, #T_0d860_row2_col0, #T_0d860_row2_col5, #T_0d860_row2_col6, #T_0d860_row2_col7, #T_0d860_row3_col0, #T_0d860_row3_col1, #T_0d860_row3_col2, #T_0d860_row3_col3, #T_0d860_row4_col4, #T_0d860_row4_col5, #T_0d860_row4_col6, #T_0d860_row5_col7, #T_0d860_row6_col0, #T_0d860_row6_col2, #T_0d860_row6_col3, #T_0d860_row7_col0, #T_0d860_row7_col1, #T_0d860_row7_col2, #T_0d860_row7_col3, #T_0d860_row7_col7 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_0d860">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d860_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_0d860_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_0d860_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_0d860_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_0d860_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_0d860_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_0d860_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_0d860_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d860_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_0d860_row0_col0" class="data row0 col0" >0.780000</td>
#       <td id="T_0d860_row0_col1" class="data row0 col1" >0.800000</td>
#       <td id="T_0d860_row0_col2" class="data row0 col2" >0.800000</td>
#       <td id="T_0d860_row0_col3" class="data row0 col3" >0.800000</td>
#       <td id="T_0d860_row0_col4" class="data row0 col4" >0.230769</td>
#       <td id="T_0d860_row0_col5" class="data row0 col5" >0.450000</td>
#       <td id="T_0d860_row0_col6" class="data row0 col6" >0.450000</td>
#       <td id="T_0d860_row0_col7" class="data row0 col7" >0.450000</td>
#     </tr>
#     <tr>
#       <th id="T_0d860_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_0d860_row1_col0" class="data row1 col0" >0.720000</td>
#       <td id="T_0d860_row1_col1" class="data row1 col1" >0.760000</td>
#       <td id="T_0d860_row1_col2" class="data row1 col2" >0.760000</td>
#       <td id="T_0d860_row1_col3" class="data row1 col3" >0.760000</td>
#       <td id="T_0d860_row1_col4" class="data row1 col4" >0.388889</td>
#       <td id="T_0d860_row1_col5" class="data row1 col5" >0.763158</td>
#       <td id="T_0d860_row1_col6" class="data row1 col6" >0.763158</td>
#       <td id="T_0d860_row1_col7" class="data row1 col7" >0.763158</td>
#     </tr>
#     <tr>
#       <th id="T_0d860_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_0d860_row2_col0" class="data row2 col0" >0.960000</td>
#       <td id="T_0d860_row2_col1" class="data row2 col1" >0.980000</td>
#       <td id="T_0d860_row2_col2" class="data row2 col2" >0.980000</td>
#       <td id="T_0d860_row2_col3" class="data row2 col3" >0.980000</td>
#       <td id="T_0d860_row2_col4" class="data row2 col4" >0.291667</td>
#       <td id="T_0d860_row2_col5" class="data row2 col5" >0.428571</td>
#       <td id="T_0d860_row2_col6" class="data row2 col6" >0.428571</td>
#       <td id="T_0d860_row2_col7" class="data row2 col7" >0.428571</td>
#     </tr>
#     <tr>
#       <th id="T_0d860_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_0d860_row3_col0" class="data row3 col0" >0.960000</td>
#       <td id="T_0d860_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_0d860_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_0d860_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0d860_row3_col4" class="data row3 col4" >0.291667</td>
#       <td id="T_0d860_row3_col5" class="data row3 col5" >0.560000</td>
#       <td id="T_0d860_row3_col6" class="data row3 col6" >0.560000</td>
#       <td id="T_0d860_row3_col7" class="data row3 col7" >0.560000</td>
#     </tr>
#     <tr>
#       <th id="T_0d860_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_0d860_row4_col0" class="data row4 col0" >0.860000</td>
#       <td id="T_0d860_row4_col1" class="data row4 col1" >0.880000</td>
#       <td id="T_0d860_row4_col2" class="data row4 col2" >0.880000</td>
#       <td id="T_0d860_row4_col3" class="data row4 col3" >0.900000</td>
#       <td id="T_0d860_row4_col4" class="data row4 col4" >0.162791</td>
#       <td id="T_0d860_row4_col5" class="data row4 col5" >0.272727</td>
#       <td id="T_0d860_row4_col6" class="data row4 col6" >0.272727</td>
#       <td id="T_0d860_row4_col7" class="data row4 col7" >0.822222</td>
#     </tr>
#     <tr>
#       <th id="T_0d860_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_0d860_row5_col0" class="data row5 col0" >0.480000</td>
#       <td id="T_0d860_row5_col1" class="data row5 col1" >0.500000</td>
#       <td id="T_0d860_row5_col2" class="data row5 col2" >0.500000</td>
#       <td id="T_0d860_row5_col3" class="data row5 col3" >0.500000</td>
#       <td id="T_0d860_row5_col4" class="data row5 col4" >0.291667</td>
#       <td id="T_0d860_row5_col5" class="data row5 col5" >0.520000</td>
#       <td id="T_0d860_row5_col6" class="data row5 col6" >0.520000</td>
#       <td id="T_0d860_row5_col7" class="data row5 col7" >0.520000</td>
#     </tr>
#     <tr>
#       <th id="T_0d860_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_0d860_row6_col0" class="data row6 col0" >0.980000</td>
#       <td id="T_0d860_row6_col1" class="data row6 col1" >0.980000</td>
#       <td id="T_0d860_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_0d860_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_0d860_row6_col4" class="data row6 col4" >0.306122</td>
#       <td id="T_0d860_row6_col5" class="data row6 col5" >0.306122</td>
#       <td id="T_0d860_row6_col6" class="data row6 col6" >0.580000</td>
#       <td id="T_0d860_row6_col7" class="data row6 col7" >0.580000</td>
#     </tr>
#     <tr>
#       <th id="T_0d860_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_0d860_row7_col0" class="data row7 col0" >0.980000</td>
#       <td id="T_0d860_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_0d860_row7_col2" class="data row7 col2" >1.000000</td>
#       <td id="T_0d860_row7_col3" class="data row7 col3" >1.000000</td>
#       <td id="T_0d860_row7_col4" class="data row7 col4" >0.346939</td>
#       <td id="T_0d860_row7_col5" class="data row7 col5" >0.520000</td>
#       <td id="T_0d860_row7_col6" class="data row7 col6" >0.520000</td>
#       <td id="T_0d860_row7_col7" class="data row7 col7" >0.520000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# -----

# %% [markdown]
# #### Assets with mediocre descriptions (50 assets)
# - description with number of characters in between <200, 500>

# %%
moderate_doc_least_df = create_hitrate_results_dataframe(model_variants, asset_quality="moderate_description_many_tags", descriptiveness_level="least_descriptive")
moderate_doc_least_df
# Out:
# <style type="text/css">
# #T_e5694 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_e5694 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_e5694_row0_col7, #T_e5694_row1_col0, #T_e5694_row1_col2, #T_e5694_row1_col5, #T_e5694_row2_col3, #T_e5694_row2_col4, #T_e5694_row2_col6, #T_e5694_row3_col1, #T_e5694_row3_col2, #T_e5694_row3_col3, #T_e5694_row4_col1, #T_e5694_row4_col2, #T_e5694_row4_col3, #T_e5694_row4_col5, #T_e5694_row4_col7, #T_e5694_row5_col6, #T_e5694_row7_col0, #T_e5694_row7_col4 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T
td>
#     </tr>
#     <tr>
#       <th id="T_ee29d_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_ee29d_row5_col0" class="data row5 col0" >0.220000</td>
#       <td id="T_ee29d_row5_col1" class="data row5 col1" >0.220000</td>
#       <td id="T_ee29d_row5_col2" class="data row5 col2" >0.220000</td>
#       <td id="T_ee29d_row5_col3" class="data row5 col3" >0.220000</td>
#       <td id="T_ee29d_row5_col4" class="data row5 col4" >0.181818</td>
#       <td id="T_ee29d_row5_col5" class="data row5 col5" >0.181818</td>
#       <td id="T_ee29d_row5_col6" class="data row5 col6" >0.181818</td>
#       <td id="T_ee29d_row5_col7" class="data row5 col7" >0.181818</td>
#     </tr>
#     <tr>
#       <th id="T_ee29d_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_ee29d_row6_col0" class="data row6 col0" >0.600000</td>
#       <td id="T_ee29d_row6_col1" class="data row6 col1" >0.620000</td>
#       <td id="T_ee29d_row6_col2" class="data row6 col2" >0.620000</td>
#       <td id="T_ee29d_row6_col3" class="data row6 col3" >0.640000</td>
#       <td id="T_ee29d_row6_col4" class="data row6 col4" >0.533333</td>
#       <td id="T_ee29d_row6_col5" class="data row6 col5" >0.709677</td>
#       <td id="T_ee29d_row6_col6" class="data row6 col6" >0.709677</td>
#       <td id="T_ee29d_row6_col7" class="data row6 col7" >1.531250</td>
#     </tr>
#     <tr>
#       <th id="T_ee29d_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_ee29d_row7_col0" class="data row7 col0" >0.800000</td>
#       <td id="T_ee29d_row7_col1" class="data row7 col1" >0.920000</td>
#       <td id="T_ee29d_row7_col2" class="data row7 col2" >0.920000</td>
#       <td id="T_ee29d_row7_col3" class="data row7 col3" >0.940000</td>
#       <td id="T_ee29d_row7_col4" class="data row7 col4" >0.450000</td>
#       <td id="T_ee29d_row7_col5" class="data row7 col5" >1.282609</td>
#       <td id="T_ee29d_row7_col6" class="data row7 col6" >1.282609</td>
#       <td id="T_ee29d_row7_col7" class="data row7 col7" >1.723404</td>
#     </tr>
#   </tbody>
# </table>

# %%
moderate_doc_most_df = create_hitrate_results_dataframe(model_variants, asset_quality="moderate_description_many_tags", descriptiveness_level="most_descriptive")
moderate_doc_most_df
# Out:
# <style type="text/css">
# #T_9ea8a td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_9ea8a tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_9ea8a_row0_col0, #T_9ea8a_row0_col1, #T_9ea8a_row1_col2, #T_9ea8a_row1_col3, #T_9ea8a_row1_col4, #T_9ea8a_row1_col5, #T_9ea8a_row2_col6, #T_9ea8a_row2_col7, #T_9ea8a_row3_col0, #T_9ea8a_row3_col1, #T_9ea8a_row3_col2, #T_9ea8a_row3_col3, #T_9ea8a_row4_col0, #T_9ea8a_row4_col1, #T_9ea8a_row4_col2, #T_9ea8a_row4_col3, #T_9ea8a_row4_col5, #T_9ea8a_row6_col4, #T_9ea8a_row7_col6, #T_9ea8a_row7_col7 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_9ea8a_row0_col6, #T_9ea8a_row0_col7, #T_9ea8a_row2_col0, #T_9ea8a_row2_col1, #T_9ea8a_row2_col2, #T_9ea8a_row2_col3, #T_9ea8a_row2_col4, #T_9ea8a_row2_col5, #T_9ea8a_row5_col4, #T_9ea8a_row5_col5, #T_9ea8a_row5_col6, #T_9ea8a_row5_col7, #T_9ea8a_row7_col0, #T_9ea8a_row7_col1, #T_9ea8a_row7_col2, #T_9ea8a_row7_col3 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_9ea8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ea8a_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_9ea8a_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_9ea8a_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_9ea8a_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_9ea8a_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_9ea8a_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_9ea8a_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_9ea8a_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ea8a_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T
row5_col4" class="data row5 col4" >0.300000</td>
#       <td id="T_9ea8a_row5_col5" class="data row5 col5" >0.300000</td>
#       <td id="T_9ea8a_row5_col6" class="data row5 col6" >0.300000</td>
#       <td id="T_9ea8a_row5_col7" class="data row5 col7" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_9ea8a_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_9ea8a_row6_col0" class="data row6 col0" >0.640000</td>
#       <td id="T_9ea8a_row6_col1" class="data row6 col1" >0.680000</td>
#       <td id="T_9ea8a_row6_col2" class="data row6 col2" >0.720000</td>
#       <td id="T_9ea8a_row6_col3" class="data row6 col3" >0.720000</td>
#       <td id="T_9ea8a_row6_col4" class="data row6 col4" >0.312500</td>
#       <td id="T_9ea8a_row6_col5" class="data row6 col5" >0.764706</td>
#       <td id="T_9ea8a_row6_col6" class="data row6 col6" >1.555556</td>
#       <td id="T_9ea8a_row6_col7" class="data row6 col7" >1.555556</td>
#     </tr>
#     <tr>
#       <th id="T_9ea8a_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_9ea8a_row7_col0" class="data row7 col0" >0.920000</td>
#       <td id="T_9ea8a_row7_col1" class="data row7 col1" >0.940000</td>
#       <td id="T_9ea8a_row7_col2" class="data row7 col2" >0.940000</td>
#       <td id="T_9ea8a_row7_col3" class="data row7 col3" >0.940000</td>
#       <td id="T_9ea8a_row7_col4" class="data row7 col4" >0.760870</td>
#       <td id="T_9ea8a_row7_col5" class="data row7 col5" >0.872340</td>
#       <td id="T_9ea8a_row7_col6" class="data row7 col6" >0.872340</td>
#       <td id="T_9ea8a_row7_col7" class="data row7 col7" >0.872340</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# -----

# %% [markdown]
# #### Assets with short to no descriptions (50 assets)
# - description with fewer than 50 characters

# %%
short_doc_least_df = create_hitrate_results_dataframe(model_variants, asset_quality="poor_description_many_tags", descriptiveness_level="least_descriptive")
short_doc_least_df
# Out:
# <style type="text/css">
# #T_64b6e td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_64b6e tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_64b6e_row0_col0, #T_64b6e_row0_col1, #T_64b6e_row0_col2, #T_64b6e_row0_col3, #T_64b6e_row1_col4, #T_64b6e_row1_col7, #T_64b6e_row2_col5, #T_64b6e_row3_col1, #T_64b6e_row3_col6, #T_64b6e_row5_col6, #T_64b6e_row5_col7, #T_64b6e_row6_col0, #T_64b6e_row7_col1, #T_64b6e_row7_col2, #T_64b6e_row7_col3, #T_64b6e_row7_col4, #T_64b6e_row7_col5 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_64b6e_row0_col5, #T_64b6e_row2_col0, #T_64b6e_row2_col1, #T_64b6e_row2_col2, #T_64b6e_row2_col3, #T_64b6e_row2_col4, #T_64b6e_row2_col6, #T_64b6e_row2_col7, #T_64b6e_row4_col0, #T_64b6e_row4_col1, #T_64b6e_row4_col2, #T_64b6e_row4_col3, #T_64b6e_row4_col4, #T_64b6e_row6_col5, #T_64b6e_row6_col6, #T_64b6e_row6_col7, #T_64b6e_row7_col0 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_64b6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64b6e_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_64b6e_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_64b6e_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_64b6e_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_64b6e_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_64b6e_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_64b6e_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_64b6e_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64b6e_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T
row5_col7" class="data row5 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_64b6e_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_64b6e_row6_col0" class="data row6 col0" >0.166667</td>
#       <td id="T_64b6e_row6_col1" class="data row6 col1" >0.166667</td>
#       <td id="T_64b6e_row6_col2" class="data row6 col2" >0.166667</td>
#       <td id="T_64b6e_row6_col3" class="data row6 col3" >0.166667</td>
#       <td id="T_64b6e_row6_col4" class="data row6 col4" >0.857143</td>
#       <td id="T_64b6e_row6_col5" class="data row6 col5" >0.857143</td>
#       <td id="T_64b6e_row6_col6" class="data row6 col6" >0.857143</td>
#       <td id="T_64b6e_row6_col7" class="data row6 col7" >0.857143</td>
#     </tr>
#     <tr>
#       <th id="T_64b6e_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_64b6e_row7_col0" class="data row7 col0" >0.261905</td>
#       <td id="T_64b6e_row7_col1" class="data row7 col1" >0.285714</td>
#       <td id="T_64b6e_row7_col2" class="data row7 col2" >0.333333</td>
#       <td id="T_64b6e_row7_col3" class="data row7 col3" >0.357143</td>
#       <td id="T_64b6e_row7_col4" class="data row7 col4" >0.727273</td>
#       <td id="T_64b6e_row7_col5" class="data row7 col5" >1.166667</td>
#       <td id="T_64b6e_row7_col6" class="data row7 col6" >2.857143</td>
#       <td id="T_64b6e_row7_col7" class="data row7 col7" >4.200000</td>
#     </tr>
#   </tbody>
# </table>

# %%
short_doc_moderate_df = create_hitrate_results_dataframe(model_variants, asset_quality="poor_description_many_tags", descriptiveness_level="moderately_descriptive")
short_doc_moderate_df
# Out:
# <style type="text/css">
# #T_53727 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_53727 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_53727_row0_col4, #T_53727_row1_col5, #T_53727_row2_col0, #T_53727_row2_col1, #T_53727_row2_col2, #T_53727_row2_col3, #T_53727_row2_col6, #T_53727_row2_col7, #T_53727_row4_col0, #T_53727_row4_col1, #T_53727_row4_col2, #T_53727_row4_col3, #T_53727_row5_col4, #T_53727_row5_col5, #T_53727_row6_col6, #T_53727_row6_col7 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# #T_53727_row1_col0, #T_53727_row1_col1, #T_53727_row1_col2, #T_53727_row1_col3, #T_53727_row1_col6, #T_53727_row1_col7, #T_53727_row2_col4, #T_53727_row2_col5, #T_53727_row4_col6, #T_53727_row4_col7, #T_53727_row6_col4, #T_53727_row6_col5, #T_53727_row7_col0, #T_53727_row7_col1, #T_53727_row7_col2, #T_53727_row7_col3 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_53727">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53727_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_53727_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_53727_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_53727_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_53727_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_53727_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_53727_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_53727_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53727_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_53727_row0_col0" class="data row0 col0" >0.309524</td>
#       <td id="T_53727_row0_col1" class="data row0 col1" >0.428571</td>
#       <td id="T_53727_row0_col2" class="data row0 col2" >0.452381</td>
#       <td id="T_53727_row0_col3" class="data row0 col3" >0.476190</td>
#       <td id="T_53727_row0_col4" class="data row0 col4" >0.076923</td>
#       <td id="T_53727_row0_col5" class="data row0 col5" >2.000000</td>
#       <td id="T_53727_row0_col6" class="data row0 col6" >2.684211</td>
#       <td id="T_53727_row0_col7" class="data row0 col7" >3.950000</td>
#     </tr>
#     <tr>
#       <th id="T_53727_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_53727_row1_col0" class="data row1 col0" >0.428571</td>
#       <td id="T_53727_row1_col1" class="data row1 col1" >0.452381</td>
#       <td id="T_53727_row1_col2" class="data row1 col2" >0.500000</td>
#       <td id="T_53727_row1_col3" class="data row1 col3" >0.500000</td>
#       <td id="T_53727_row1_col4" class="data row1 col4" >0.611111</td>
#       <td id="T_53727_row1_col5" class="data row1 col5" >0.947368</td>
#       <td id="T_53727_row1_col6" class="data row1 col6" >2.523810</td>
#       <td id="T_53727_row1_col7" class="data row1 col7" >2.523810</td>
#     </tr>
#     <tr>
#       <th id="T_53727_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T
level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_53727_row7_col0" class="data row7 col0" >0.261905</td>
#       <td id="T_53727_row7_col1" class="data row7 col1" >0.285714</td>
#       <td id="T_53727_row7_col2" class="data row7 col2" >0.380952</td>
#       <td id="T_53727_row7_col3" class="data row7 col3" >0.404762</td>
#       <td id="T_53727_row7_col4" class="data row7 col4" >0.727273</td>
#       <td id="T_53727_row7_col5" class="data row7 col5" >1.250000</td>
#       <td id="T_53727_row7_col6" class="data row7 col6" >4.625000</td>
#       <td id="T_53727_row7_col7" class="data row7 col7" >5.588235</td>
#     </tr>
#   </tbody>
# </table>

# %%
short_doc_most_df = create_hitrate_results_dataframe(model_variants, asset_quality="poor_description_many_tags", descriptiveness_level="most_descriptive")
short_doc_most_df
# Out:
# <style type="text/css">
# #T_9ffb8 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_9ffb8 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_9ffb8_row0_col0, #T_9ffb8_row0_col1, #T_9ffb8_row0_col2, #T_9ffb8_row0_col6, #T_9ffb8_row1_col5, #T_9ffb8_row1_col7, #T_9ffb8_row2_col3, #T_9ffb8_row2_col4, #T_9ffb8_row4_col4, #T_9ffb8_row4_col5, #T_9ffb8_row4_col6, #T_9ffb8_row5_col7, #T_9ffb8_row7_col0, #T_9ffb8_row7_col1, #T_9ffb8_row7_col2, #T_9ffb8_row7_col3 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_9ffb8_row0_col3, #T_9ffb8_row0_col4, #T_9ffb8_row2_col0, #T_9ffb8_row2_col1, #T_9ffb8_row2_col2, #T_9ffb8_row2_col5, #T_9ffb8_row2_col6, #T_9ffb8_row2_col7, #T_9ffb8_row4_col0, #T_9ffb8_row4_col1, #T_9ffb8_row4_col2, #T_9ffb8_row4_col3, #T_9ffb8_row6_col4, #T_9ffb8_row6_col7, #T_9ffb8_row7_col5, #T_9ffb8_row7_col6 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_9ffb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ffb8_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_9ffb8_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_9ffb8_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_9ffb8_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_9ffb8_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_9ffb8_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_9ffb8_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_9ffb8_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ffb8_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_9ffb8_row0_col0" class="data row0 col0" >0.500000</td>
#       <td id="T_9ffb8_row0_col1" class="data row0 col1" >0.547619</td>
#       <td id="T_9ffb8_row0_col2" class="data row0 col2" >0.595238</td>
#       <td id="T_9ffb8_row0_col3" class="data row0 col3" >0.690476</td>
#       <td id="T_9ffb8_row0_col4" class="data row0 col4" >0.380952</td>
#       <td id="T_9ffb8_row0_col5" class="data row0 col5" >0.869565</td>
#       <td id="T_9ffb8_row0_col6" class="data row0 col6" >1.840000</td>
#       <td id="T_9ffb8_row0_col7" class="data row0 col7" >4.931034</td>
#     </tr>
#     <tr>
#       <th id="T_9ffb8_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_9ffb8_row1_col0" class="data row1 col0" >0.452381</td>
#       <td id="T_9ffb8_row1_col1" class="data row1 col1" >0.452381</td>
#       <td id="T_9ffb8_row1_col2" class="data row1 col2" >0.523810</td>
#       <td id="T_9ffb8_row1_col3" class="data row1 col3" >0.523810</td>
#       <td id="T_9ffb8_row1_col4" class="data row1 col4" >0.631579</td>
#       <td id="T_9ffb8_row1_col5" class="data row1 col5" >0.631579</td>
#       <td id="T_9ffb8_row1_col6" class="data row1 col6" >2.500000</td>
#       <td id="T_9ffb8_row1_col7" class="data row1 col7" >2.500000</td>
#     </tr>
#     <tr>
#       <th id="T_9ffb8_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_9ffb8_row2_col0" class="data row2 col0" >0.595238</td>
#       <td id="T_9ffb8_row2_col1" class="data row2 col1" >0.595238</td>
#       <td id="T_9ffb8_row2_col2" class="data row2 col2" >0.642857</td>
#       <td id="T_9ffb8_row2_col3" class="data row2 col3" >0.666667</td>
#       <td id="T_9ffb8_row2_col4" class="data row2 col4" >0.400000</td>
#       <td id="T_9ffb8_row2_col5" class="data row2 col5" >0.400000</td>
#       <td id="T_9ffb8_row2_col6" class="data row2 col6" >1.333333</td>
#       <td id="T_9ffb8_row2_col7" class="data row2 col7" >2.107143</td>
#     </tr>
#     <tr>
#       <th id="T_9ffb8_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T
td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Analyzing influence of asset_quality on retrieval performance

# %% [markdown]
# **long_description_many_tags** (150 queries)

# %%
df = create_hitrate_results_dataframe(model_variants, asset_quality="long_description_many_tags", descriptiveness_level="all")
df
# Out:
# <style type="text/css">
# #T_f07f6 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_f07f6 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_f07f6_row0_col4, #T_f07f6_row0_col5, #T_f07f6_row0_col6, #T_f07f6_row0_col7, #T_f07f6_row3_col0, #T_f07f6_row3_col1, #T_f07f6_row3_col2, #T_f07f6_row3_col3, #T_f07f6_row4_col4, #T_f07f6_row4_col6, #T_f07f6_row4_col7, #T_f07f6_row5_col5, #T_f07f6_row7_col0, #T_f07f6_row7_col1, #T_f07f6_row7_col2, #T_f07f6_row7_col3 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# #T_f07f6_row2_col0, #T_f07f6_row2_col1, #T_f07f6_row2_col2, #T_f07f6_row2_col3, #T_f07f6_row3_col4, #T_f07f6_row3_col5, #T_f07f6_row3_col6, #T_f07f6_row3_col7, #T_f07f6_row4_col0, #T_f07f6_row4_col1, #T_f07f6_row4_col5, #T_f07f6_row5_col4, #T_f07f6_row6_col2, #T_f07f6_row6_col3, #T_f07f6_row7_col6, #T_f07f6_row7_col7 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_f07f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f07f6_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_f07f6_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_f07f6_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_f07f6_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_f07f6_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_f07f6_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_f07f6_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_f07f6_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f07f6_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_f07f6_row0_col0" class="data row0 col0" >0.800000</td>
#       <td id="T_f07f6_row0_col1" class="data row0 col1" >0.826667</td>
#       <td id="T_f07f6_row0_col2" class="data row0 col2" >0.840000</td>
#       <td id="T_f07f6_row0_col3" class="data row0 col3" >0.846667</td>
#       <td id="T_f07f6_row0_col4" class="data row0 col4" >0.366667</td>
#       <td id="T_f07f6_row0_col5" class="data row0 col5" >0.564516</td>
#       <td id="T_f07f6_row0_col6" class="data row0 col6" >0.722222</td>
#       <td id="T_f07f6_row0_col7" class="data row0 col7" >0.921260</td>
#     </tr>
#     <tr>
#       <th id="T_f07f6_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T_f07f6_row1_col0" class="data row1 col0" >0.686667</td>
#       <td id="T_f07f6_row1_col1" class="data row1 col1" >0.733333</td>
#       <td id="T_f07f6_row1_col2" class="data row1 col2" >0.760000</td>
#       <td id="T_f07f6_row1_col3" class="data row1 col3" >0.766667</td>
#       <td id="T_f07f6_row1_col4" class="data row1 col4" >0.504854</td>
#       <td id="T_f07f6_row1_col5" class="data row1 col5" >0.909091</td>
#       <td id="T_f07f6_row1_col6" class="data row1 col6" >1.342105</td>
#       <td id="T_f07f6_row1_col7" class="data row1 col7" >1.513043</td>
#     </tr>
#     <tr>
#       <th id="T_f07f6_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_f07f6_row2_col0" class="data row2 col0" >0.826667</td>
#       <td id="T_f07f6_row2_col1" class="data row2 col1" >0.886667</td>
#       <td id="T_f07f6_row2_col2" class="data row2 col2" >0.920000</td>
#       <td id="T_f07f6_row2_col3" class="data row2 col3" >0.926667</td>
#       <td id="T_f07f6_row2_col4" class="data row2 col4" >0.516129</td>
#       <td id="T_f07f6_row2_col5" class="data row2 col5" >0.954887</td>
#       <td id="T_f07f6_row2_col6" class="data row2 col6" >1.427536</td>
#       <td id="T_f07f6_row2_col7" class="data row2 col7" >1.575540</td>
#     </tr>
#     <tr>
#       <th id="T_f07f6_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_f07f6_row3_col0" class="data row3 col0" >0.906667</td>
#       <td id="T_f07f6_row3_col1" class="data row3 col1" >0.966667</td>
#       <td id="T_f07f6_row3_col2" class="data row3 col2" >0.973333</td>
#       <td id="T_f07f6_row3_col3" class="data row3 col3" >0.986667</td>
#       <td id="T_f07f6_row3_col4" class="data row3 col4" >0.382353</td>
#       <td id="T_f07f6_row3_col5" class="data row3 col5" >0.751724</td>
#       <td id="T_f07f6_row3_col6" class="data row3 col6" >0.835616</td>
#       <td id="T_f07f6_row3_col7" class="data row3 col7" >1.175676</td>
#     </tr>
#     <tr>
#       <th id="T_f07f6_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_f07f6_row4_col0" class="data row4 col0" >0.833333</td>
#       <td id="T_f07f6_row4_col1" class="data row4 col1" >0.866667</td>
#       <td id="T_f07f6_row4_col2" class="data row4 col2" >0.873333</td>
#       <td id="T_f07f6_row4_col3" class="data row4 col3" >0.880000</td>
#       <td id="T_f07f6_row4_col4" class="data row4 col4" >0.344000</td>
#       <td id="T_f07f6_row4_col5" class="data row4 col5" >0.553846</td>
#       <td id="T_f07f6_row4_col6" class="data row4 col6" >0.641221</td>
#       <td id="T_f07f6_row4_col7" class="data row4 col7" >0.825758</td>
#     </tr>
#     <tr>
#       <th id="T_f07f6_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_f07f6_row5_col0" class="data row5 col0" >0.406667</td>
#       <td id="T_f07f6_row5_col1" class="data row5 col1" >0.420000</td>
#       <td id="T_f07f6_row5_col2" class="data row5 col2" >0.433333</td>
#       <td id="T_f07f6_row5_col3" class="data row5 col3" >0.433333</td>
#       <td id="T_f07f6_row5_col4" class="data row5 col4" >0.344262</td>
#       <td id="T_f07f6_row5_col5" class="data row5 col5" >0.523810</td>
#       <td id="T_f07f6_row5_col6" class="data row5 col6" >0.938462</td>
#       <td id="T_f07f6_row5_col7" class="data row5 col7" >0.938462</td>
#     </tr>
#     <tr>
#       <th id="T_f07f6_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_f07f6_row6_col0" class="data row6 col0" >0.813333</td>
#       <td id="T_f07f6_row6_col1" class="data row6 col1" >0.840000</td>
#       <td id="T_f07f6_row6_col2" class="data row6 col2" >0.900000</td>
#       <td id="T_f07f6_row6_col3" class="data row6 col3" >0.920000</td>
#       <td id="T_f07f6_row6_col4" class="data row6 col4" >0.581967</td>
#       <td id="T_f07f6_row6_col5" class="data row6 col5" >0.738095</td>
#       <td id="T_f07f6_row6_col6" class="data row6 col6" >1.688889</td>
#       <td id="T_f07f6_row6_col7" class="data row6 col7" >2.239130</td>
#     </tr>
#     <tr>
#       <th id="T_f07f6_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_f07f6_row7_col0" class="data row7 col0" >0.946667</td>
#       <td id="T_f07f6_row7_col1" class="data row7 col1" >0.980000</td>
#       <td id="T_f07f6_row7_col2" class="data row7 col2" >0.980000</td>
#       <td id="T_f07f6_row7_col3" class="data row7 col3" >0.986667</td>
#       <td id="T_f07f6_row7_col4" class="data row7 col4" >0.471831</td>
#       <td id="T_f07f6_row7_col5" class="data row7 col5" >0.721088</td>
#       <td id="T_f07f6_row7_col6" class="data row7 col6" >0.721088</td>
#       <td id="T_f07f6_row7_col7" class="data row7 col7" >0.891892</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **long_description_few_tags** (150 queries)

# %%
df = create_hitrate_results_dataframe(model_variants, asset_quality="long_description_few_tags", descriptiveness_level="all")
df
# Out:
# <style type="text/css">
# #T_1e42a td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_1e42a tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T
td>
#     </tr>
#     <tr>
#       <th id="T_1e42a_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_1e42a_row4_col0" class="data row4 col0" >0.633333</td>
#       <td id="T_1e42a_row4_col1" class="data row4 col1" >0.713333</td>
#       <td id="T_1e42a_row4_col2" class="data row4 col2" >0.753333</td>
#       <td id="T_1e42a_row4_col3" class="data row4 col3" >0.786667</td>
#       <td id="T_1e42a_row4_col4" class="data row4 col4" >0.905263</td>
#       <td id="T_1e42a_row4_col5" class="data row4 col5" >1.551402</td>
#       <td id="T_1e42a_row4_col6" class="data row4 col6" >2.141593</td>
#       <td id="T_1e42a_row4_col7" class="data row4 col7" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1e42a_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_1e42a_row5_col0" class="data row5 col0" >0.353333</td>
#       <td id="T_1e42a_row5_col1" class="data row5 col1" >0.386667</td>
#       <td id="T_1e42a_row5_col2" class="data row5 col2" >0.400000</td>
#       <td id="T_1e42a_row5_col3" class="data row5 col3" >0.406667</td>
#       <td id="T_1e42a_row5_col4" class="data row5 col4" >1.113208</td>
#       <td id="T_1e42a_row5_col5" class="data row5 col5" >1.586207</td>
#       <td id="T_1e42a_row5_col6" class="data row5 col6" >2.033333</td>
#       <td id="T_1e42a_row5_col7" class="data row5 col7" >2.393443</td>
#     </tr>
#     <tr>
#       <th id="T_1e42a_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_1e42a_row6_col0" class="data row6 col0" >0.593333</td>
#       <td id="T_1e42a_row6_col1" class="data row6 col1" >0.686667</td>
#       <td id="T_1e42a_row6_col2" class="data row6 col2" >0.713333</td>
#       <td id="T_1e42a_row6_col3" class="data row6 col3" >0.753333</td>
#       <td id="T_1e42a_row6_col4" class="data row6 col4" >0.977528</td>
#       <td id="T_1e42a_row6_col5" class="data row6 col5" >1.689320</td>
#       <td id="T_1e42a_row6_col6" class="data row6 col6" >2.289720</td>
#       <td id="T_1e42a_row6_col7" class="data row6 col7" >3.415929</td>
#     </tr>
#     <tr>
#       <th id="T_1e42a_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_1e42a_row7_col0" class="data row7 col0" >0.513333</td>
#       <td id="T_1e42a_row7_col1" class="data row7 col1" >0.633333</td>
#       <td id="T_1e42a_row7_col2" class="data row7 col2" >0.706667</td>
#       <td id="T_1e42a_row7_col3" class="data row7 col3" >0.760000</td>
#       <td id="T_1e42a_row7_col4" class="data row7 col4" >1.116883</td>
#       <td id="T_1e42a_row7_col5" class="data row7 col5" >2.242105</td>
#       <td id="T_1e42a_row7_col6" class="data row7 col6" >3.424528</td>
#       <td id="T_1e42a_row7_col7" class="data row7 col7" >4.798246</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **moderate_description_many_tags** (150 queries)

# %%
df = create_hitrate_results_dataframe(model_variants, asset_quality="moderate_description_many_tags", descriptiveness_level="all")
df
# Out:
# <style type="text/css">
# #T_6b0b9 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_6b0b9 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_6b0b9_row0_col7, #T_6b0b9_row1_col0, #T_6b0b9_row1_col5, #T_6b0b9_row2_col4, #T_6b0b9_row2_col6, #T_6b0b9_row3_col0, #T_6b0b9_row3_col1, #T_6b0b9_row3_col2, #T_6b0b9_row3_col3, #T_6b0b9_row4_col0, #T_6b0b9_row4_col1, #T_6b0b9_row4_col2, #T_6b0b9_row4_col3, #T_6b0b9_row4_col5, #T_6b0b9_row4_col6, #T_6b0b9_row6_col4, #T_6b0b9_row7_col7 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T
td>
#     </tr>
#     <tr>
#       <th id="T_6b0b9_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_6b0b9_row4_col0" class="data row4 col0" >0.800000</td>
#       <td id="T_6b0b9_row4_col1" class="data row4 col1" >0.826667</td>
#       <td id="T_6b0b9_row4_col2" class="data row4 col2" >0.860000</td>
#       <td id="T_6b0b9_row4_col3" class="data row4 col3" >0.886667</td>
#       <td id="T_6b0b9_row4_col4" class="data row4 col4" >0.591667</td>
#       <td id="T_6b0b9_row4_col5" class="data row4 col5" >0.798387</td>
#       <td id="T_6b0b9_row4_col6" class="data row4 col6" >1.271318</td>
#       <td id="T_6b0b9_row4_col7" class="data row4 col7" >1.969925</td>
#     </tr>
#     <tr>
#       <th id="T_6b0b9_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_6b0b9_row5_col0" class="data row5 col0" >0.280000</td>
#       <td id="T_6b0b9_row5_col1" class="data row5 col1" >0.286667</td>
#       <td id="T_6b0b9_row5_col2" class="data row5 col2" >0.286667</td>
#       <td id="T_6b0b9_row5_col3" class="data row5 col3" >0.286667</td>
#       <td id="T_6b0b9_row5_col4" class="data row5 col4" >0.476190</td>
#       <td id="T_6b0b9_row5_col5" class="data row5 col5" >0.581395</td>
#       <td id="T_6b0b9_row5_col6" class="data row5 col6" >0.581395</td>
#       <td id="T_6b0b9_row5_col7" class="data row5 col7" >0.581395</td>
#     </tr>
#     <tr>
#       <th id="T_6b0b9_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_6b0b9_row6_col0" class="data row6 col0" >0.573333</td>
#       <td id="T_6b0b9_row6_col1" class="data row6 col1" >0.600000</td>
#       <td id="T_6b0b9_row6_col2" class="data row6 col2" >0.633333</td>
#       <td id="T_6b0b9_row6_col3" class="data row6 col3" >0.640000</td>
#       <td id="T_6b0b9_row6_col4" class="data row6 col4" >0.523256</td>
#       <td id="T_6b0b9_row6_col5" class="data row6 col5" >0.822222</td>
#       <td id="T_6b0b9_row6_col6" class="data row6 col6" >1.589474</td>
#       <td id="T_6b0b9_row6_col7" class="data row6 col7" >1.854167</td>
#     </tr>
#     <tr>
#       <th id="T_6b0b9_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_6b0b9_row7_col0" class="data row7 col0" >0.813333</td>
#       <td id="T_6b0b9_row7_col1" class="data row7 col1" >0.886667</td>
#       <td id="T_6b0b9_row7_col2" class="data row7 col2" >0.913333</td>
#       <td id="T_6b0b9_row7_col3" class="data row7 col3" >0.920000</td>
#       <td id="T_6b0b9_row7_col4" class="data row7 col4" >0.672131</td>
#       <td id="T_6b0b9_row7_col5" class="data row7 col5" >1.195489</td>
#       <td id="T_6b0b9_row7_col6" class="data row7 col6" >1.496350</td>
#       <td id="T_6b0b9_row7_col7" class="data row7 col7" >1.644928</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **poor_description_many_tags** (150 queries)

# %%
df = create_hitrate_results_dataframe(model_variants, asset_quality="poor_description_many_tags", descriptiveness_level="all")
df
# Out:
# <style type="text/css">
# #T_83f65 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_83f65 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_83f65_row0_col0, #T_83f65_row0_col1, #T_83f65_row0_col2, #T_83f65_row0_col3, #T_83f65_row0_col4, #T_83f65_row0_col6, #T_83f65_row1_col0, #T_83f65_row1_col7, #T_83f65_row2_col5, #T_83f65_row4_col4, #T_83f65_row5_col7, #T_83f65_row6_col5, #T_83f65_row7_col0, #T_83f65_row7_col1, #T_83f65_row7_col2, #T_83f65_row7_col3, #T_83f65_row7_col6 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T
td>
#     </tr>
#     <tr>
#       <th id="T_83f65_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_83f65_row4_col0" class="data row4 col0" >0.365079</td>
#       <td id="T_83f65_row4_col1" class="data row4 col1" >0.428571</td>
#       <td id="T_83f65_row4_col2" class="data row4 col2" >0.515873</td>
#       <td id="T_83f65_row4_col3" class="data row4 col3" >0.547619</td>
#       <td id="T_83f65_row4_col4" class="data row4 col4" >0.608696</td>
#       <td id="T_83f65_row4_col5" class="data row4 col5" >1.537037</td>
#       <td id="T_83f65_row4_col6" class="data row4 col6" >3.769231</td>
#       <td id="T_83f65_row4_col7" class="data row4 col7" >5.014493</td>
#     </tr>
#     <tr>
#       <th id="T_83f65_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_83f65_row5_col0" class="data row5 col0" >0.055556</td>
#       <td id="T_83f65_row5_col1" class="data row5 col1" >0.063492</td>
#       <td id="T_83f65_row5_col2" class="data row5 col2" >0.079365</td>
#       <td id="T_83f65_row5_col3" class="data row5 col3" >0.079365</td>
#       <td id="T_83f65_row5_col4" class="data row5 col4" >0.857143</td>
#       <td id="T_83f65_row5_col5" class="data row5 col5" >1.750000</td>
#       <td id="T_83f65_row5_col6" class="data row5 col6" >4.400000</td>
#       <td id="T_83f65_row5_col7" class="data row5 col7" >4.400000</td>
#     </tr>
#     <tr>
#       <th id="T_83f65_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_83f65_row6_col0" class="data row6 col0" >0.158730</td>
#       <td id="T_83f65_row6_col1" class="data row6 col1" >0.182540</td>
#       <td id="T_83f65_row6_col2" class="data row6 col2" >0.214286</td>
#       <td id="T_83f65_row6_col3" class="data row6 col3" >0.214286</td>
#       <td id="T_83f65_row6_col4" class="data row6 col4" >0.500000</td>
#       <td id="T_83f65_row6_col5" class="data row6 col5" >1.217391</td>
#       <td id="T_83f65_row6_col6" class="data row6 col6" >3.000000</td>
#       <td id="T_83f65_row6_col7" class="data row6 col7" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83f65_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_83f65_row7_col0" class="data row7 col0" >0.309524</td>
#       <td id="T_83f65_row7_col1" class="data row7 col1" >0.333333</td>
#       <td id="T_83f65_row7_col2" class="data row7 col2" >0.404762</td>
#       <td id="T_83f65_row7_col3" class="data row7 col3" >0.436508</td>
#       <td id="T_83f65_row7_col4" class="data row7 col4" >0.692308</td>
#       <td id="T_83f65_row7_col5" class="data row7 col5" >1.095238</td>
#       <td id="T_83f65_row7_col6" class="data row7 col6" >3.196078</td>
#       <td id="T_83f65_row7_col7" class="data row7 col7" >4.727273</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Analyzing influence of descriptiveness level on retrieval performance

# %% [markdown]
# **Least_descriptive** (200 queries)

# %%
least_descriptive_df = create_hitrate_results_dataframe(model_variants, asset_quality="all", descriptiveness_level="least_descriptive")
least_descriptive_df
# Out:
# <style type="text/css">
# #T_1ce11 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_1ce11 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_1ce11_row0_col5, #T_1ce11_row0_col6, #T_1ce11_row1_col4, #T_1ce11_row2_col0, #T_1ce11_row2_col1, #T_1ce11_row2_col2, #T_1ce11_row2_col3, #T_1ce11_row2_col7, #T_1ce11_row4_col4, #T_1ce11_row4_col5, #T_1ce11_row4_col6, #T_1ce11_row5_col7, #T_1ce11_row7_col0, #T_1ce11_row7_col1, #T_1ce11_row7_col2, #T_1ce11_row7_col3 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# #T_1ce11_row0_col7, #T_1ce11_row1_col6, #T_1ce11_row2_col4, #T_1ce11_row2_col5, #T_1ce11_row3_col0, #T_1ce11_row3_col1, #T_1ce11_row3_col2, #T_1ce11_row3_col3, #T_1ce11_row4_col0, #T_1ce11_row4_col1, #T_1ce11_row4_col2, #T_1ce11_row4_col3, #T_1ce11_row4_col7, #T_1ce11_row5_col6, #T_1ce11_row6_col5, #T_1ce11_row7_col4 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_1ce11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ce11_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T
td>
#     </tr>
#     <tr>
#       <th id="T_1ce11_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_1ce11_row5_col0" class="data row5 col0" >0.234375</td>
#       <td id="T_1ce11_row5_col1" class="data row5 col1" >0.250000</td>
#       <td id="T_1ce11_row5_col2" class="data row5 col2" >0.265625</td>
#       <td id="T_1ce11_row5_col3" class="data row5 col3" >0.270833</td>
#       <td id="T_1ce11_row5_col4" class="data row5 col4" >0.977778</td>
#       <td id="T_1ce11_row5_col5" class="data row5 col5" >1.291667</td>
#       <td id="T_1ce11_row5_col6" class="data row5 col6" >2.039216</td>
#       <td id="T_1ce11_row5_col7" class="data row5 col7" >2.461538</td>
#     </tr>
#     <tr>
#       <th id="T_1ce11_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_1ce11_row6_col0" class="data row6 col0" >0.489583</td>
#       <td id="T_1ce11_row6_col1" class="data row6 col1" >0.515625</td>
#       <td id="T_1ce11_row6_col2" class="data row6 col2" >0.567708</td>
#       <td id="T_1ce11_row6_col3" class="data row6 col3" >0.588542</td>
#       <td id="T_1ce11_row6_col4" class="data row6 col4" >1.031915</td>
#       <td id="T_1ce11_row6_col5" class="data row6 col5" >1.272727</td>
#       <td id="T_1ce11_row6_col6" class="data row6 col6" >2.568807</td>
#       <td id="T_1ce11_row6_col7" class="data row6 col7" >3.336283</td>
#     </tr>
#     <tr>
#       <th id="T_1ce11_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_1ce11_row7_col0" class="data row7 col0" >0.604167</td>
#       <td id="T_1ce11_row7_col1" class="data row7 col1" >0.661458</td>
#       <td id="T_1ce11_row7_col2" class="data row7 col2" >0.708333</td>
#       <td id="T_1ce11_row7_col3" class="data row7 col3" >0.729167</td>
#       <td id="T_1ce11_row7_col4" class="data row7 col4" >0.844828</td>
#       <td id="T_1ce11_row7_col5" class="data row7 col5" >1.393701</td>
#       <td id="T_1ce11_row7_col6" class="data row7 col6" >2.147059</td>
#       <td id="T_1ce11_row7_col7" class="data row7 col7" >2.771429</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Moderately_descriptive** (200 queries)

# %%
moderately_descriptive_df = create_hitrate_results_dataframe(model_variants, asset_quality="all", descriptiveness_level="moderately_descriptive")
moderately_descriptive_df
# Out:
# <style type="text/css">
# #T_0e1ba td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_0e1ba tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_0e1ba_row0_col6, #T_0e1ba_row1_col7, #T_0e1ba_row2_col4, #T_0e1ba_row2_col5, #T_0e1ba_row3_col0, #T_0e1ba_row3_col1, #T_0e1ba_row3_col2, #T_0e1ba_row3_col3, #T_0e1ba_row4_col2, #T_0e1ba_row4_col3, #T_0e1ba_row4_col5, #T_0e1ba_row4_col6, #T_0e1ba_row4_col7, #T_0e1ba_row7_col0, #T_0e1ba_row7_col1, #T_0e1ba_row7_col4 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_0e1ba_row1_col4, #T_0e1ba_row1_col5, #T_0e1ba_row2_col0, #T_0e1ba_row2_col1, #T_0e1ba_row2_col2, #T_0e1ba_row2_col3, #T_0e1ba_row2_col6, #T_0e1ba_row2_col7, #T_0e1ba_row4_col0, #T_0e1ba_row4_col1, #T_0e1ba_row5_col4, #T_0e1ba_row5_col5, #T_0e1ba_row5_col6, #T_0e1ba_row5_col7, #T_0e1ba_row7_col2, #T_0e1ba_row7_col3 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_0e1ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e1ba_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_0e1ba_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_0e1ba_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_0e1ba_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_0e1ba_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_0e1ba_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_0e1ba_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_0e1ba_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e1ba_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_0e1ba_level0_row5" class="row_heading level0 row5" >multilingual_e5_large--relevant</th>
#       <td id="T_0e1ba_row5_col0" class="data row5 col0" >0.260417</td>
#       <td id="T_0e1ba_row5_col1" class="data row5 col1" >0.270833</td>
#       <td id="T_0e1ba_row5_col2" class="data row5 col2" >0.281250</td>
#       <td id="T_0e1ba_row5_col3" class="data row5 col3" >0.281250</td>
#       <td id="T_0e1ba_row5_col4" class="data row5 col4" >0.540000</td>
#       <td id="T_0e1ba_row5_col5" class="data row5 col5" >0.750000</td>
#       <td id="T_0e1ba_row5_col6" class="data row5 col6" >1.277778</td>
#       <td id="T_0e1ba_row5_col7" class="data row5 col7" >1.277778</td>
#     </tr>
#     <tr>
#       <th id="T_0e1ba_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_0e1ba_row6_col0" class="data row6 col0" >0.531250</td>
#       <td id="T_0e1ba_row6_col1" class="data row6 col1" >0.578125</td>
#       <td id="T_0e1ba_row6_col2" class="data row6 col2" >0.614583</td>
#       <td id="T_0e1ba_row6_col3" class="data row6 col3" >0.635417</td>
#       <td id="T_0e1ba_row6_col4" class="data row6 col4" >0.666667</td>
#       <td id="T_0e1ba_row6_col5" class="data row6 col5" >1.099099</td>
#       <td id="T_0e1ba_row6_col6" class="data row6 col6" >1.966102</td>
#       <td id="T_0e1ba_row6_col7" class="data row6 col7" >2.811475</td>
#     </tr>
#     <tr>
#       <th id="T_0e1ba_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_0e1ba_row7_col0" class="data row7 col0" >0.645833</td>
#       <td id="T_0e1ba_row7_col1" class="data row7 col1" >0.718750</td>
#       <td id="T_0e1ba_row7_col2" class="data row7 col2" >0.765625</td>
#       <td id="T_0e1ba_row7_col3" class="data row7 col3" >0.791667</td>
#       <td id="T_0e1ba_row7_col4" class="data row7 col4" >0.596774</td>
#       <td id="T_0e1ba_row7_col5" class="data row7 col5" >1.260870</td>
#       <td id="T_0e1ba_row7_col6" class="data row7 col6" >2.061224</td>
#       <td id="T_0e1ba_row7_col7" class="data row7 col7" >2.723684</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Most_descriptive** (200 queries)

# %%
most_descriptive_df = create_hitrate_results_dataframe(model_variants, asset_quality="all", descriptiveness_level="most_descriptive")
most_descriptive_df
# Out:
# <style type="text/css">
# #T_86e4a td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_86e4a tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_86e4a_row0_col0, #T_86e4a_row1_col4, #T_86e4a_row1_col5, #T_86e4a_row2_col6, #T_86e4a_row2_col7, #T_86e4a_row3_col1, #T_86e4a_row3_col2, #T_86e4a_row3_col3, #T_86e4a_row4_col1, #T_86e4a_row4_col4, #T_86e4a_row4_col6, #T_86e4a_row5_col5, #T_86e4a_row6_col7, #T_86e4a_row7_col0, #T_86e4a_row7_col2, #T_86e4a_row7_col3 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_86e4a_row0_col6, #T_86e4a_row1_col7, #T_86e4a_row2_col0, #T_86e4a_row2_col1, #T_86e4a_row2_col2, #T_86e4a_row2_col3, #T_86e4a_row2_col4, #T_86e4a_row2_col5, #T_86e4a_row4_col0, #T_86e4a_row4_col2, #T_86e4a_row4_col3, #T_86e4a_row4_col5, #T_86e4a_row5_col6, #T_86e4a_row5_col7, #T_86e4a_row6_col4, #T_86e4a_row7_col1 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_86e4a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86e4a_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_86e4a_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_86e4a_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_86e4a_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_86e4a_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_86e4a_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_86e4a_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_86e4a_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86e4a_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_86e4a_row0_col0" class="data row0 col0" >0.723958</td>
#       <td id="T_86e4a_row0_col1" class="data row0 col1" >0.760417</td>
#       <td id="T_86e4a_row0_col2" class="data row0 col2" >0.781250</td>
#       <td id="T_86e4a_row0_col3" class="data row0 col3" >0.807292</td>
#       <td id="T_86e4a_row0_col4" class="data row0 col4" >0.532374</td>
#       <td id="T_86e4a_row0_col5" class="data row0 col5" >0.821918</td>
#       <td id="T_86e4a_row0_col6" class="data row0 col6" >1.173333</td>
#       <td id="T_86e4a_row0_col7" class="data row0 col7" >1.890323</td>
#     </tr>
#     <tr>
#       <th id="T_86e4a_level0_row1" class="row_heading level0 row1" >multilingual_e5_large--basic</th>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_86e4a_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_86e4a_row6_col0" class="data row6 col0" >0.630208</td>
#       <td id="T_86e4a_row6_col1" class="data row6 col1" >0.687500</td>
#       <td id="T_86e4a_row6_col2" class="data row6 col2" >0.713542</td>
#       <td id="T_86e4a_row6_col3" class="data row6 col3" >0.723958</td>
#       <td id="T_86e4a_row6_col4" class="data row6 col4" >0.396694</td>
#       <td id="T_86e4a_row6_col5" class="data row6 col5" >0.916667</td>
#       <td id="T_86e4a_row6_col6" class="data row6 col6" >1.408759</td>
#       <td id="T_86e4a_row6_col7" class="data row6 col7" >1.683453</td>
#     </tr>
#     <tr>
#       <th id="T_86e4a_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_86e4a_row7_col0" class="data row7 col0" >0.729167</td>
#       <td id="T_86e4a_row7_col1" class="data row7 col1" >0.791667</td>
#       <td id="T_86e4a_row7_col2" class="data row7 col2" >0.822917</td>
#       <td id="T_86e4a_row7_col3" class="data row7 col3" >0.848958</td>
#       <td id="T_86e4a_row7_col4" class="data row7 col4" >0.642857</td>
#       <td id="T_86e4a_row7_col5" class="data row7 col5" >1.138158</td>
#       <td id="T_86e4a_row7_col6" class="data row7 col6" >1.531646</td>
#       <td id="T_86e4a_row7_col7" class="data row7 col7" >2.233129</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## ALL results
#
# **ALL** (averaged all the results -> around ~600 queries)

# %%
all_df = create_hitrate_results_dataframe(model_variants, asset_quality="all", descriptiveness_level="all")
all_df
# Out:
# <style type="text/css">
# #T_56765 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_56765 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_56765_row0_col6, #T_56765_row2_col0, #T_56765_row2_col1, #T_56765_row2_col2, #T_56765_row2_col3, #T_56765_row2_col4, #T_56765_row2_col5, #T_56765_row2_col7, #T_56765_row4_col0, #T_56765_row4_col4, #T_56765_row5_col5, #T_56765_row5_col6, #T_56765_row5_col7, #T_56765_row7_col1, #T_56765_row7_col2, #T_56765_row7_col3 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# #T_56765_row1_col4, #T_56765_row1_col5, #T_56765_row1_col7, #T_56765_row2_col6, #T_56765_row3_col0, #T_56765_row3_col1, #T_56765_row3_col2, #T_56765_row3_col3, #T_56765_row4_col1, #T_56765_row4_col2, #T_56765_row4_col3, #T_56765_row4_col5, #T_56765_row4_col6, #T_56765_row4_col7, #T_56765_row5_col4, #T_56765_row7_col0 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_56765">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56765_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_56765_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_56765_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_56765_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_56765_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_56765_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_56765_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_56765_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56765_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_56765_row0_col0" class="data row0 col0" >0.637153</td>
#       <td id="T_56765_row0_col1" class="data row0 col1" >0.699653</td>
#       <td id="T_56765_row0_col2" class="data row0 col2" >0.727431</td>
#       <td id="T_56765_row0_col3" class="data row0 col3" >0.746528</td>
#       <td id="T_56765_row0_col4" class="data row0 col4" >0.602180</td>
#       <td id="T_56765_row0_col5" class="data row0 col5" >1.124069</td>
#       <td id="T_56765_row0_col6" class="data row0 col6" >1.584726</td>
#       <td id="T_56765_row0_col7" class="data row0 col7" >2.162791</td>
#     </tr>
#     <tr>
#       <th id="T_56765_level0_
level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_56765_row7_col0" class="data row7 col0" >0.659722</td>
#       <td id="T_56765_row7_col1" class="data row7 col1" >0.723958</td>
#       <td id="T_56765_row7_col2" class="data row7 col2" >0.765625</td>
#       <td id="T_56765_row7_col3" class="data row7 col3" >0.789931</td>
#       <td id="T_56765_row7_col4" class="data row7 col4" >0.689474</td>
#       <td id="T_56765_row7_col5" class="data row7 col5" >1.256595</td>
#       <td id="T_56765_row7_col6" class="data row7 col6" >1.897959</td>
#       <td id="T_56765_row7_col7" class="data row7 col7" >2.562637</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Hit-rate evaluation conclusion
#
# - Field extraction strategy has strong effect on the results of the models:
#     - GTE/BGE performs very similarly (BGE outperforms the GTE slightly) in both extraction strategies
#         - performs better on relevant fields
#     - E5 (chunk)
#         - performs better on basic fields with description
#         - on relevant fields with little to no description, there is a drop in performance when comparing it to the results of GTE/BGE
#             - due to the sensitivity to its input we want to avoid this model if possible I suppose

# %% [markdown]
# -----

# %% [markdown]
# # Conclusions
#
# - GTE models performs the best on precision evaluation, but achieves worse performance on hit-rate evaluation compared to BGE
# - E5 model applied on basic fields performs the best on hit-rate evaluation, however its results plummet once you apply the model to relevant fields
#     - Hence we prefer using more stable models: GTE/BGE
#
# **TODO:**
# - We need to test how good GTE model is when applied to seperate chunks rather than whole documents
#
# **CURRENT MODEL SELECTIONS:**
#
# *If we were to select the best model from the current results, we would choose:*
#
# - GTE_large (relevant fields) -> as an embedding model only (HIGH PRECISION)
#
# - GTE_large/BGE_large (relevant fields) -> as a retrieval part of RAG pipeline (HIGH RECALL)

# %% [markdown]
# # Comparison of the best models
#
# In this section we will look at the overall results of the following 3 models using both types of field extraction techniques:
# - GTE_large (document embeddings store)
# - GTE_large (chunk embeddings store)
# - BGE_large (chunk embeddings store)

# %% [markdown]
# ## PRECISION EVALUATION

# %%
model_variants = [
    # basic dataset representations
    "gte_large--basic",
    "gte_large_hierarchical--CHUNK_EMBEDS--basic",
    "bge_large--CHUNK_EMBEDS--basic",

    # relevant dataset representations
    "gte_large--relevant",
    "gte_large_hierarchical--CHUNK_EMBEDS--relevant",
    "bge_large--CHUNK_EMBEDS--relevant"
]

# %% [markdown]
# **LLM predictions - All queries** (90 queries)

# %%
all_df = create_precision_results_dataframe(model_variants, descriptiveness_level="all", function_score="llm_scores")
all_df
# Out:
# <style type="text/css">
# #T_390a5 td:nth-child(4) {
#   border-right: 4px solid white;
# }
# #T_390a5 tr:nth-child(3) {
#   border-bottom: 4px solid white;
# }
# #T_390a5_row0_col0, #T_390a5_row0_col1, #T_390a5_row0_col2, #T_390a5_row1_col3, #T_390a5_row1_col4, #T_390a5_row1_col5, #T_390a5_row3_col1, #T_390a5_row3_col2, #T_390a5_row3_col3, #T_390a5_row3_col4, #T_390a5_row3_col5, #T_390a5_row5_col0 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_390a5_row0_col3, #T_390a5_row0_col4, #T_390a5_row0_col5, #T_390a5_row1_col0, #T_390a5_row1_col1, #T_390a5_row1_col2, #T_390a5_row3_col0, #T_390a5_row4_col0, #T_390a5_row4_col1, #T_390a5_row4_col2, #T_390a5_row4_col3, #T_390a5_row4_col4, #T_390a5_row4_col5 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_390a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_390a5_level0_col0" class="col_heading level0 col0" >prec@3</th>
#       <th id="T_390a5_level0_col1" class="col_heading level0 col1" >prec@5</th>
#       <th id="T_390a5_level0_col2" class="col_heading level0 col2" >prec@10</th>
#       <th id="T_390a5_level0_col3" class="col_heading level0 col3" >ndcg@3</th>
#       <th id="T_390a5_level0_col4" class="col_heading level0 col4" >ndcg@5</th>
#       <th id="T_390a5_level0_col5" class="col_heading level0 col5" >ndcg@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_390a5_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_390a5_row0_col0" class="data row0 col0" >0.695035</td>
#       <td id="T_390a5_row0_col1" class="data row0 col1" >0.668085</td>
#       <td id="T_390a5_row0_col2" class="data row0 col2" >0.638298</td>
#       <td id="T_390a5_row0_col3" class="data row0 col3" >0.967204</td>
#       <td id="T_390a5_row0_col4" class="data row0 col4" >0.948121</td>
#       <td id="T_390a5_row0_col5" class="data row0 col5" >0.933412</td>
#     </tr>
#     <tr>
#       <th id="T_390a5_level0_row1" class="row_heading level0 row1" >gte_large_hierarchical--CHUNK_EMBEDS--basic</th>
#       <td id="T_390a5_row1_col0" class="data row1 col0" >0.755319</td>
#       <td id="T_390a5_row1_col1" class="data row1 col1" >0.708511</td>
#       <td id="T_390a5_row1_col2" class="data row1 col2" >0.681915</td>
#       <td id="T_390a5_row1_col3" class="data row1 col3" >0.957709</td>
#       <td id="T_390a5_row1_col4" class="data row1 col4" >0.944415</td>
#       <td id="T_390a5_row1_col5" class="data row1 col5" >0.927771</td>
#     </tr>
#     <tr>
#       <th id="T_390a5_level0_row2" class="row_heading level0 row2" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_390a5_row2_col0" class="data row2 col0" >0.599291</td>
#       <td id="T_390a5_row2_col1" class="data row2 col1" >0.576596</td>
#       <td id="T_390a5_row2_col2" class="data row2 col2" >0.590426</td>
#       <td id="T_390a5_row2_col3" class="data row2 col3" >0.939337</td>
#       <td id="T_390a5_row2_col4" class="data row2 col4" >0.917686</td>
#       <td id="T_390a5_row2_col5" class="data row2 col5" >0.887910</td>
#     </tr>
#     <tr>
#       <th id="T_390a5_level0_row3" class="row_heading level0 row3" >gte_large--relevant</th>
#       <td id="T_390a5_row3_col0" class="data row3 col0" >0.808511</td>
#       <td id="T_390a5_row3_col1" class="data row3 col1" >0.761702</td>
#       <td id="T_390a5_row3_col2" class="data row3 col2" >0.722340</td>
#       <td id="T_390a5_row3_col3" class="data row3 col3" >0.956565</td>
#       <td id="T_390a5_row3_col4" class="data row3 col4" >0.945786</td>
#       <td id="T_390a5_row3_col5" class="data row3 col5" >0.933756</td>
#     </tr>
#     <tr>
#       <th id="T_390a5_level0_row4" class="row_heading level0 row4" >gte_large_hierarchical--CHUNK_EMBEDS--relevant</th>
#       <td id="T_390a5_row4_col0" class="data row4 col0" >0.808511</td>
#       <td id="T_390a5_row4_col1" class="data row4 col1" >0.770213</td>
#       <td id="T_390a5_row4_col2" class="data row4 col2" >0.735106</td>
#       <td id="T_390a5_row4_col3" class="data row4 col3" >0.959514</td>
#       <td id="T_390a5_row4_col4" class="data row4 col4" >0.953607</td>
#       <td id="T_390a5_row4_col5" class="data row4 col5" >0.938973</td>
#     </tr>
#     <tr>
#       <th id="T_390a5_level0_row5" class="row_heading level0 row5" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_390a5_row5_col0" class="data row5 col0" >0.677305</td>
#       <td id="T_390a5_row5_col1" class="data row5 col1" >0.687234</td>
#       <td id="T_390a5_row5_col2" class="data row5 col2" >0.680851</td>
#       <td id="T_390a5_row5_col3" class="data row5 col3" >0.947572</td>
#       <td id="T_390a5_row5_col4" class="data row5 col4" >0.932023</td>
#       <td id="T_390a5_row5_col5" class="data row5 col5" >0.913666</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Heuristic predictions - All queries** (90 queries)

# %%
all_df = create_precision_results_dataframe(model_variants, descriptiveness_level="all", function_score="heuristic_scores")
all_df
# Out:
# <style type="text/css">
# #T_be4a3 td:nth-child(4) {
#   border-right: 4px solid white;
# }
# #T_be4a3 tr:nth-child(3) {
#   border-bottom: 4px solid white;
# }
# #T_be4a3_row0_col0, #T_be4a3_row0_col1, #T_be4a3_row0_col2, #T_be4a3_row2_col3, #T_be4a3_row2_col4, #T_be4a3_row2_col5, #T_be4a3_row3_col0, #T_be4a3_row3_col1, #T_be4a3_row3_col2, #T_be4a3_row3_col3, #T_be4a3_row3_col4, #T_be4a3_row5_col5 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_be4a3_row1_col0, #T_be4a3_row1_col1, #T_be4a3_row1_col2, #T_be4a3_row1_col3, #T_be4a3_row1_col4, #T_be4a3_row1_col5, #T_be4a3_row4_col0, #T_be4a3_row4_col1, #T_be4a3_row4_col2, #T_be4a3_row4_col3, #T_be4a3_row4_col4, #T_be4a3_row4_col5 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_be4a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be4a3_level0_col0" class="col_heading level0 col0" >prec@3</th>
#       <th id="T_be4a3_level0_col1" class="col_heading level0 col1" >prec@5</th>
#       <th id="T_be4a3_level0_col2" class="col_heading level0 col2" >prec@10</th>
#       <th id="T_be4a3_level0_col3" class="col_heading level0 col3" >ndcg@3</th>
#       <th id="T_be4a3_level0_col4" class="col_heading level0 col4" >ndcg@5</th>
#       <th id="T_be4a3_level0_col5" class="col_heading level0 col5" >ndcg@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be4a3_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_be4a3_row0_col0" class="data row0 col0" >0.620567</td>
#       <td id="T_be4a3_row0_col1" class="data row0 col1" >0.580851</td>
#       <td id="T_be4a3_row0_col2" class="data row0 col2" >0.542553</td>
#       <td id="T_be4a3_row0_col3" class="data row0 col3" >0.852151</td>
#       <td id="T_be4a3_row0_col4" class="data row0 col4" >0.833096</td>
#       <td id="T_be4a3_row0_col5" class="data row0 col5" >0.815375</td>
#     </tr>
#     <tr>
#       <th id="T_be4a3_level0_row1" class="row_heading level0 row1" >gte_large_hierarchical--CHUNK_EMBEDS--basic</th>
#       <td id="T_be4a3_row1_col0" class="data row1 col0" >0.624113</td>
#       <td id="T_be4a3_row1_col1" class="data row1 col1" >0.604255</td>
#       <td id="T_be4a3_row1_col2" class="data row1 col2" >0.581915</td>
#       <td id="T_be4a3_row1_col3" class="data row1 col3" >0.894000</td>
#       <td id="T_be4a3_row1_col4" class="data row1 col4" >0.870545</td>
#       <td id="T_be4a3_row1_col5" class="data row1 col5" >0.844550</td>
#     </tr>
#     <tr>
#       <th id="T_be4a3_level0_row2" class="row_heading level0 row2" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_be4a3_row2_col0" class="data row2 col0" >0.482270</td>
#       <td id="T_be4a3_row2_col1" class="data row2 col1" >0.465957</td>
#       <td id="T_be4a3_row2_col2" class="data row2 col2" >0.481915</td>
#       <td id="T_be4a3_row2_col3" class="data row2 col3" >0.863816</td>
#       <td id="T_be4a3_row2_col4" class="data row2 col4" >0.848940</td>
#       <td id="T_be4a3_row2_col5" class="data row2 col5" >0.817540</td>
#     </tr>
#     <tr>
#       <th id="T_be4a3_level0_row3" class="row_heading level0 row3" >gte_large--relevant</th>
#       <td id="T_be4a3_row3_col0" class="data row3 col0" >0.695035</td>
#       <td id="T_be4a3_row3_col1" class="data row3 col1" >0.657447</td>
#       <td id="T_be4a3_row3_col2" class="data row3 col2" >0.624468</td>
#       <td id="T_be4a3_row3_col3" class="data row3 col3" >0.920008</td>
#       <td id="T_be4a3_row3_col4" class="data row3 col4" >0.899954</td>
#       <td id="T_be4a3_row3_col5" class="data row3 col5" >0.874371</td>
#     </tr>
#     <tr>
#       <th id="T_be4a3_level0_row4" class="row_heading level0 row4" >gte_large_hierarchical--CHUNK_EMBEDS--relevant</th>
#       <td id="T_be4a3_row4_col0" class="data row4 col0" >0.709220</td>
#       <td id="T_be4a3_row4_col1" class="data row4 col1" >0.680851</td>
#       <td id="T_be4a3_row4_col2" class="data row4 col2" >0.626596</td>
#       <td id="T_be4a3_row4_col3" class="data row4 col3" >0.934196</td>
#       <td id="T_be4a3_row4_col4" class="data row4 col4" >0.919122</td>
#       <td id="T_be4a3_row4_col5" class="data row4 col5" >0.894310</td>
#     </tr>
#     <tr>
#       <th id="T_be4a3_level0_row5" class="row_heading level0 row5" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_be4a3_row5_col0" class="data row5 col0" >0.606383</td>
#       <td id="T_be4a3_row5_col1" class="data row5 col1" >0.612766</td>
#       <td id="T_be4a3_row5_col2" class="data row5 col2" >0.603191</td>
#       <td id="T_be4a3_row5_col3" class="data row5 col3" >0.909513</td>
#       <td id="T_be4a3_row5_col4" class="data row5 col4" >0.894001</td>
#       <td id="T_be4a3_row5_col5" class="data row5 col5" >0.875721</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Precision final conclusion
#
# - GTE hiearchical version achievies similar or even better results than the GTE on average
#     - This approach is more generic and capable of dealing with arbitrary long documents, making it more versatile and robust than working with a token limit of 4k and storing the representations of the whole documents

# %% [markdown]
# ## HIT RATE EVALUATION

# %%
model_variants = [
    # basic dataset representations
    "gte_large--basic",
    "gte_large_hierarchical--CHUNK_EMBEDS--basic",
    "multilingual_e5_large--CHUNK_EMBEDS--basic",
    "bge_large--CHUNK_EMBEDS--basic",

    # relevant dataset representations
    "gte_large--relevant",
    "gte_large_hierarchical--CHUNK_EMBEDS--relevant",
    "multilingual_e5_large--CHUNK_EMBEDS--relevant",
    "bge_large--CHUNK_EMBEDS--relevant"
]

# %% [markdown]
# **Least_descriptive queries** (200 queries)

# %%
least_descriptive_df = create_hitrate_results_dataframe(model_variants, asset_quality="all", descriptiveness_level="least_descriptive")
least_descriptive_df
# Out:
# <style type="text/css">
# #T_6f031 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_6f031 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_6f031_row0_col5, #T_6f031_row0_col6, #T_6f031_row1_col0, #T_6f031_row1_col1, #T_6f031_row1_col2, #T_6f031_row1_col3, #T_6f031_row1_col4, #T_6f031_row2_col7, #T_6f031_row4_col6, #T_6f031_row4_col7, #T_6f031_row5_col0, #T_6f031_row5_col1, #T_6f031_row5_col2, #T_6f031_row5_col3, #T_6f031_row5_col4, #T_6f031_row5_col5 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
td>
#     </tr>
#     <tr>
#       <th id="T_6f031_level0_row5" class="row_heading level0 row5" >gte_large_hierarchical--CHUNK_EMBEDS--relevant</th>
#       <td id="T_6f031_row5_col0" class="data row5 col0" >0.614583</td>
#       <td id="T_6f031_row5_col1" class="data row5 col1" >0.671875</td>
#       <td id="T_6f031_row5_col2" class="data row5 col2" >0.718750</td>
#       <td id="T_6f031_row5_col3" class="data row5 col3" >0.755208</td>
#       <td id="T_6f031_row5_col4" class="data row5 col4" >0.677966</td>
#       <td id="T_6f031_row5_col5" class="data row5 col5" >1.224806</td>
#       <td id="T_6f031_row5_col6" class="data row5 col6" >2.152174</td>
#       <td id="T_6f031_row5_col7" class="data row5 col7" >3.200000</td>
#     </tr>
#     <tr>
#       <th id="T_6f031_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_6f031_row6_col0" class="data row6 col0" >0.489583</td>
#       <td id="T_6f031_row6_col1" class="data row6 col1" >0.515625</td>
#       <td id="T_6f031_row6_col2" class="data row6 col2" >0.567708</td>
#       <td id="T_6f031_row6_col3" class="data row6 col3" >0.588542</td>
#       <td id="T_6f031_row6_col4" class="data row6 col4" >1.031915</td>
#       <td id="T_6f031_row6_col5" class="data row6 col5" >1.272727</td>
#       <td id="T_6f031_row6_col6" class="data row6 col6" >2.568807</td>
#       <td id="T_6f031_row6_col7" class="data row6 col7" >3.336283</td>
#     </tr>
#     <tr>
#       <th id="T_6f031_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_6f031_row7_col0" class="data row7 col0" >0.604167</td>
#       <td id="T_6f031_row7_col1" class="data row7 col1" >0.661458</td>
#       <td id="T_6f031_row7_col2" class="data row7 col2" >0.708333</td>
#       <td id="T_6f031_row7_col3" class="data row7 col3" >0.729167</td>
#       <td id="T_6f031_row7_col4" class="data row7 col4" >0.844828</td>
#       <td id="T_6f031_row7_col5" class="data row7 col5" >1.393701</td>
#       <td id="T_6f031_row7_col6" class="data row7 col6" >2.147059</td>
#       <td id="T_6f031_row7_col7" class="data row7 col7" >2.771429</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Moderately_descriptive** (200 queries)

# %%
moderately_descriptive_df = create_hitrate_results_dataframe(model_variants, asset_quality="all", descriptiveness_level="moderately_descriptive")
moderately_descriptive_df
# Out:
# <style type="text/css">
# #T_00e4f td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_00e4f tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_00e4f_row0_col4, #T_00e4f_row0_col6, #T_00e4f_row1_col0, #T_00e4f_row1_col7, #T_00e4f_row2_col1, #T_00e4f_row2_col2, #T_00e4f_row3_col3, #T_00e4f_row3_col5, #T_00e4f_row4_col2, #T_00e4f_row4_col3, #T_00e4f_row4_col5, #T_00e4f_row4_col7, #T_00e4f_row5_col0, #T_00e4f_row5_col1, #T_00e4f_row5_col3, #T_00e4f_row5_col4, #T_00e4f_row5_col6, #T_00e4f_row7_col1 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_00e4f_row1_col1, #T_00e4f_row1_col2, #T_00e4f_row1_col3, #T_00e4f_row2_col0, #T_00e4f_row2_col3, #T_00e4f_row2_col4, #T_00e4f_row2_col5, #T_00e4f_row2_col6, #T_00e4f_row2_col7, #T_00e4f_row4_col0, #T_00e4f_row4_col1, #T_00e4f_row4_col6, #T_00e4f_row5_col2, #T_00e4f_row5_col5, #T_00e4f_row5_col7, #T_00e4f_row7_col2, #T_00e4f_row7_col3, #T_00e4f_row7_col4 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_00e4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00e4f_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_00e4f_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_00e4f_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_00e4f_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_00e4f_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_00e4f_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_00e4f_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_00e4f_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00e4f_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T
row5_col0" class="data row5 col0" >0.666667</td>
#       <td id="T_00e4f_row5_col1" class="data row5 col1" >0.718750</td>
#       <td id="T_00e4f_row5_col2" class="data row5 col2" >0.765625</td>
#       <td id="T_00e4f_row5_col3" class="data row5 col3" >0.781250</td>
#       <td id="T_00e4f_row5_col4" class="data row5 col4" >0.617188</td>
#       <td id="T_00e4f_row5_col5" class="data row5 col5" >1.050725</td>
#       <td id="T_00e4f_row5_col6" class="data row5 col6" >1.782313</td>
#       <td id="T_00e4f_row5_col7" class="data row5 col7" >2.193333</td>
#     </tr>
#     <tr>
#       <th id="T_00e4f_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_00e4f_row6_col0" class="data row6 col0" >0.531250</td>
#       <td id="T_00e4f_row6_col1" class="data row6 col1" >0.578125</td>
#       <td id="T_00e4f_row6_col2" class="data row6 col2" >0.614583</td>
#       <td id="T_00e4f_row6_col3" class="data row6 col3" >0.635417</td>
#       <td id="T_00e4f_row6_col4" class="data row6 col4" >0.666667</td>
#       <td id="T_00e4f_row6_col5" class="data row6 col5" >1.099099</td>
#       <td id="T_00e4f_row6_col6" class="data row6 col6" >1.966102</td>
#       <td id="T_00e4f_row6_col7" class="data row6 col7" >2.811475</td>
#     </tr>
#     <tr>
#       <th id="T_00e4f_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_00e4f_row7_col0" class="data row7 col0" >0.645833</td>
#       <td id="T_00e4f_row7_col1" class="data row7 col1" >0.718750</td>
#       <td id="T_00e4f_row7_col2" class="data row7 col2" >0.765625</td>
#       <td id="T_00e4f_row7_col3" class="data row7 col3" >0.791667</td>
#       <td id="T_00e4f_row7_col4" class="data row7 col4" >0.596774</td>
#       <td id="T_00e4f_row7_col5" class="data row7 col5" >1.260870</td>
#       <td id="T_00e4f_row7_col6" class="data row7 col6" >2.061224</td>
#       <td id="T_00e4f_row7_col7" class="data row7 col7" >2.723684</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Most_descriptive** (200 queries)

# %%
most_descriptive_df = create_hitrate_results_dataframe(model_variants, asset_quality="all", descriptiveness_level="most_descriptive")
most_descriptive_df
# Out:
# <style type="text/css">
# #T_ed031 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_ed031 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_ed031_row0_col6, #T_ed031_row1_col2, #T_ed031_row1_col4, #T_ed031_row1_col5, #T_ed031_row1_col7, #T_ed031_row2_col0, #T_ed031_row2_col1, #T_ed031_row3_col3, #T_ed031_row4_col0, #T_ed031_row4_col3, #T_ed031_row4_col4, #T_ed031_row4_col5, #T_ed031_row4_col6, #T_ed031_row5_col7, #T_ed031_row7_col1, #T_ed031_row7_col2 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_ed031_row1_col0, #T_ed031_row1_col1, #T_ed031_row1_col3, #T_ed031_row1_col6, #T_ed031_row2_col2, #T_ed031_row2_col3, #T_ed031_row2_col4, #T_ed031_row2_col5, #T_ed031_row2_col7, #T_ed031_row4_col2, #T_ed031_row5_col0, #T_ed031_row5_col1, #T_ed031_row5_col2, #T_ed031_row5_col3, #T_ed031_row5_col5, #T_ed031_row5_col6, #T_ed031_row6_col4, #T_ed031_row6_col7 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_ed031">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed031_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_ed031_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_ed031_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_ed031_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_ed031_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_ed031_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_ed031_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_ed031_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed031_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_ed031_row0_col0" class="data row0 col0" >0.723958</td>
#       <td id="T_ed031_row0_col1" class="data row0 col1" >0.760417</td>
#       <td id="T_ed031_row0_col2" class="data row0 col2" >0.781250</td>
#       <td id="T_ed031_row0_col3" class="data row0 col3" >0.807292</td>
#       <td id="T_ed031_row0_col4" class="data row0 col4" >0.532374</td>
#       <td id="T_ed031_row0_col5" class="data row0 col5" >0.821918</td>
#       <td id="T_ed031_row0_col6" class="data row0 col6" >1.173333</td>
#       <td id="T_ed031_row0_col7" class="data row0 col7" >1.890323</td>
#     </tr>
#     <tr>
#       <th id="T_ed031_level0_row1" class="row_heading level0 row1" >gte_large_hierarchical--CHUNK_EMBEDS--basic</th>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_ed031_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_ed031_row6_col0" class="data row6 col0" >0.630208</td>
#       <td id="T_ed031_row6_col1" class="data row6 col1" >0.687500</td>
#       <td id="T_ed031_row6_col2" class="data row6 col2" >0.713542</td>
#       <td id="T_ed031_row6_col3" class="data row6 col3" >0.723958</td>
#       <td id="T_ed031_row6_col4" class="data row6 col4" >0.396694</td>
#       <td id="T_ed031_row6_col5" class="data row6 col5" >0.916667</td>
#       <td id="T_ed031_row6_col6" class="data row6 col6" >1.408759</td>
#       <td id="T_ed031_row6_col7" class="data row6 col7" >1.683453</td>
#     </tr>
#     <tr>
#       <th id="T_ed031_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_ed031_row7_col0" class="data row7 col0" >0.729167</td>
#       <td id="T_ed031_row7_col1" class="data row7 col1" >0.791667</td>
#       <td id="T_ed031_row7_col2" class="data row7 col2" >0.822917</td>
#       <td id="T_ed031_row7_col3" class="data row7 col3" >0.848958</td>
#       <td id="T_ed031_row7_col4" class="data row7 col4" >0.642857</td>
#       <td id="T_ed031_row7_col5" class="data row7 col5" >1.138158</td>
#       <td id="T_ed031_row7_col6" class="data row7 col6" >1.531646</td>
#       <td id="T_ed031_row7_col7" class="data row7 col7" >2.233129</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **ALL queries** (averaged all the results -> around ~600 queries)

# %%
all_df = create_hitrate_results_dataframe(model_variants, asset_quality="all", descriptiveness_level="all")
all_df
# Out:
# <style type="text/css">
# #T_cf6a8 td:nth-child(5) {
#   border-right: 4px solid white;
# }
# #T_cf6a8 tr:nth-child(4) {
#   border-bottom: 4px solid white;
# }
# #T_cf6a8_row0_col5, #T_cf6a8_row1_col0, #T_cf6a8_row1_col4, #T_cf6a8_row1_col6, #T_cf6a8_row1_col7, #T_cf6a8_row2_col1, #T_cf6a8_row2_col2, #T_cf6a8_row2_col3, #T_cf6a8_row4_col0, #T_cf6a8_row4_col4, #T_cf6a8_row4_col5, #T_cf6a8_row4_col6, #T_cf6a8_row5_col7, #T_cf6a8_row7_col1, #T_cf6a8_row7_col2, #T_cf6a8_row7_col3 {
#   background-color: rgba(255, 165, 0, 0.3);
#   color: white;
# }
# #T_cf6a8_row0_col6, #T_cf6a8_row1_col1, #T_cf6a8_row1_col2, #T_cf6a8_row1_col3, #T_cf6a8_row2_col0, #T_cf6a8_row2_col4, #T_cf6a8_row2_col5, #T_cf6a8_row2_col7, #T_cf6a8_row4_col7, #T_cf6a8_row5_col0, #T_cf6a8_row5_col1, #T_cf6a8_row5_col2, #T_cf6a8_row5_col3, #T_cf6a8_row5_col4, #T_cf6a8_row5_col5, #T_cf6a8_row5_col6 {
#   background-color: rgba(255, 0, 0, 0.3);
#   color: white;
# }
# </style>
# <table id="T_cf6a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf6a8_level0_col0" class="col_heading level0 col0" >asset_hit_rate@5</th>
#       <th id="T_cf6a8_level0_col1" class="col_heading level0 col1" >asset_hit_rate@10</th>
#       <th id="T_cf6a8_level0_col2" class="col_heading level0 col2" >asset_hit_rate@20</th>
#       <th id="T_cf6a8_level0_col3" class="col_heading level0 col3" >asset_hit_rate@30</th>
#       <th id="T_cf6a8_level0_col4" class="col_heading level0 col4" >asset_position@5</th>
#       <th id="T_cf6a8_level0_col5" class="col_heading level0 col5" >asset_position@10</th>
#       <th id="T_cf6a8_level0_col6" class="col_heading level0 col6" >asset_position@20</th>
#       <th id="T_cf6a8_level0_col7" class="col_heading level0 col7" >asset_position@30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Input Config</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf6a8_level0_row0" class="row_heading level0 row0" >gte_large--basic</th>
#       <td id="T_cf6a8_row0_col0" class="data row0 col0" >0.637153</td>
#       <td id="T_cf6a8_row0_col1" class="data row0 col1" >0.699653</td>
#       <td id="T_cf6a8_row0_col2" class="data row0 col2" >0.727431</td>
#       <td id="T_cf6a8_row0_col3" class="data row0 col3" >0.746528</td>
#       <td id="T_cf6a8_row0_col4" class="data row0 col4" >0.602180</td>
#       <td id="T_cf6a8_row0_col5" class="data row0 col5" >1.124069</td>
#       <td id="T_cf6a8_row0_col6" class="data row0 col6" >1.584726</td>
#       <td id="T_cf6a8_row0_col7" class="data row0 col7" >2.162791</td>
#     </tr>
#     <tr>
#       <th id="T_cf6a8_level0_row1" class="row_heading level0 row1" >gte_large_hierarchical--CHUNK_EMBEDS--basic</th>
#       <td id="T_cf6a8_row1_col0" class="data row1 col0" >0.699653</td>
#       <td id="T_cf6a8_row1_col1" class="data row1 col1" >0.774306</td>
#       <td id="T_cf6a8_row1_col2" class="data row1 col2" >0.807292</td>
#       <td id="T_cf6a8_row1_col3" class="data row1 col3" >0.821181</td>
#       <td id="T_cf6a8_row1_col4" class="data row1 col4" >0.553350</td>
#       <td id="T_cf6a8_row1_col5" class="data row1 col5" >1.143498</td>
#       <td id="T_cf6a8_row1_col6" class="data row1 col6" >1.640860</td>
#       <td id="T_cf6a8_row1_col7" class="data row1 col7" >2.044397</td>
#     </tr>
#     <tr>
#       <th id="T_cf6a8_level0_row2" class="row_heading level0 row2" >multilingual_e5_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_cf6a8_row2_col0" class="data row2 col0" >0.701389</td>
#       <td id="T_cf6a8_row2_col1" class="data row2 col1" >0.755208</td>
#       <td id="T_cf6a8_row2_col2" class="data row2 col2" >0.802083</td>
#       <td id="T_cf6a8_row2_col3" class="data row2 col3" >0.809028</td>
#       <td id="T_cf6a8_row2_col4" class="data row2 col4" >0.504950</td>
#       <td id="T_cf6a8_row2_col5" class="data row2 col5" >0.958621</td>
#       <td id="T_cf6a8_row2_col6" class="data row2 col6" >1.757576</td>
#       <td id="T_cf6a8_row2_col7" class="data row2 col7" >1.939914</td>
#     </tr>
#     <tr>
#       <th id="T_cf6a8_level0_row3" class="row_heading level0 row3" >bge_large--CHUNK_EMBEDS--basic</th>
#       <td id="T_cf6a8_row3_col0" class="data row3 col0" >0.642361</td>
#       <td id="T_cf6a8_row3_col1" class="data row3 col1" >0.708333</td>
#       <td id="T_cf6a8_row3_col2" class="data row3 col2" >0.770833</td>
#       <td id="T_cf6a8_row3_col3" class="data row3 col3" >0.786458</td>
#       <td id="T_cf6a8_row3_col4" class="data row3 col4" >0.664865</td>
#       <td id="T_cf6a8_row3_col5" class="data row3 col5" >1.203431</td>
#       <td id="T_cf6a8_row3_col6" class="data row3 col6" >2.283784</td>
#       <td id="T_cf6a8_row3_col7" class="data row3 col7" >2.706402</td>
#     </tr>
#     <tr>
#       <th id="T_cf6a8_level0_row4" class="row_heading level0 row4" >gte_large--relevant</th>
#       <td id="T_cf6a8_row4_col0" class="data row4 col0" >0.670139</td>
#       <td id="T_cf6a8_row4_col1" class="data row4 col1" >0.720486</td>
#       <td id="T_cf6a8_row4_col2" class="data row4 col2" >0.760417</td>
#       <td id="T_cf6a8_row4_col3" class="data row4 col3" >0.784722</td>
#       <td id="T_cf6a8_row4_col4" class="data row4 col4" >0.590674</td>
#       <td id="T_cf6a8_row4_col5" class="data row4 col5" >1.012048</td>
#       <td id="T_cf6a8_row4_col6" class="data row4 col6" >1.678082</td>
#       <td id="T_cf6a8_row4_col7" class="data row4 col7" >2.369469</td>
#     </tr>
#     <tr>
#       <th id="T_cf6a8_level0_row5" class="row_heading level0 row5" >gte_large_hierarchical--CHUNK_EMBEDS--relevant</th>
#       <td id="T_cf6a8_row5_col0" class="data row5 col0" >0.685764</td>
#       <td id="T_cf6a8_row5_col1" class="data row5 col1" >0.732639</td>
#       <td id="T_cf6a8_row5_col2" class="data row5 col2" >0.770833</td>
#       <td id="T_cf6a8_row5_col3" class="data row5 col3" >0.800347</td>
#       <td id="T_cf6a8_row5_col4" class="data row5 col4" >0.582278</td>
#       <td id="T_cf6a8_row5_col5" class="data row5 col5" >0.966825</td>
#       <td id="T_cf6a8_row5_col6" class="data row5 col6" >1.605856</td>
#       <td id="T_cf6a8_row5_col7" class="data row5 col7" >2.412148</td>
#     </tr>
#     <tr>
#       <th id="T_cf6a8_level0_row6" class="row_heading level0 row6" >multilingual_e5_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_cf6a8_row6_col0" class="data row6 col0" >0.550347</td>
#       <td id="T_cf6a8_row6_col1" class="data row6 col1" >0.593750</td>
#       <td id="T_cf6a8_row6_col2" class="data row6 col2" >0.631944</td>
#       <td id="T_cf6a8_row6_col3" class="data row6 col3" >0.649306</td>
#       <td id="T_cf6a8_row6_col4" class="data row6 col4" >0.671924</td>
#       <td id="T_cf6a8_row6_col5" class="data row6 col5" >1.078947</td>
#       <td id="T_cf6a8_row6_col6" class="data row6 col6" >1.936813</td>
#       <td id="T_cf6a8_row6_col7" class="data row6 col7" >2.550802</td>
#     </tr>
#     <tr>
#       <th id="T_cf6a8_level0_row7" class="row_heading level0 row7" >bge_large--CHUNK_EMBEDS--relevant</th>
#       <td id="T_cf6a8_row7_col0" class="data row7 col0" >0.659722</td>
#       <td id="T_cf6a8_row7_col1" class="data row7 col1" >0.723958</td>
#       <td id="T_cf6a8_row7_col2" class="data row7 col2" >0.765625</td>
#       <td id="T_cf6a8_row7_col3" class="data row7 col3" >0.789931</td>
#       <td id="T_cf6a8_row7_col4" class="data row7 col4" >0.689474</td>
#       <td id="T_cf6a8_row7_col5" class="data row7 col5" >1.256595</td>
#       <td id="T_cf6a8_row7_col6" class="data row7 col6" >1.897959</td>
#       <td id="T_cf6a8_row7_col7" class="data row7 col7" >2.562637</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Hitrate final conclusion
#
# - GTE hierarchical version was able to beat the peformance of the E5-basic_fields model
#     - However due to increase in precision performance, we still prefer using relevant fields extraction to retrieve more information that may be crucial to the user query
#         - By applying chunking and computing chunk embeddings separatelly, we dont weed to worry about prolonging the document textual represenations that may potentionally cause the whole document representations to be more generic in the case of storing the whole document embeddings

# %% [markdown]
# # THE VERY BEST MODEL
#
# - Based on our conducted evaluations, we identified the GTE_large (hierarchical) model to be the best out of all evaluated embedding models
#     - This model can be used either seperately or as a part of RAG pipeline or any other pipeline in a retrieval system
